# %% [markdown]
# ### Setup

# %%
# %pip install schedule bitsandbytes -q

# %% [markdown]
# ### Clone GitHub Repository and Add to System Path

# %%
# --- Configuration for your GitHub Repository ---
GITHUB_REPO_URL = "https://github.com/JackMclaughlin424/csci739-project-mamba.git" # Replace with your GitHub repository URL
REPO_NAME = "csci739-project-mamba"
COMMIT_HASH = None # Set this to a specific commit hash (e.g., "your_commit_hash") to check out that commit. If None, the latest commit on the specified branch will be used.
BRANCH_NAME = "experiments" # Set this to the name of the branch you want to clone (e.g., "dev", "main"). If None, the default branch will be cloned.
SUBDIRECTORY = "" # If your project code is in a subdirectory (e.g., 'Colab resources/style-prompt-generator'), specify it here. Otherwise, set to None or an empty string.

# %% [markdown]
# **Clear GitHub Repository**

# %%
import shutil
import os

# Ensure REPO_NAME is defined (it should be from previous cells)
if 'REPO_NAME' in globals() and REPO_NAME:
    repo_path = f'/content/{REPO_NAME}'
    if os.path.exists(repo_path):
        print(f'Removing {repo_path}...')
        shutil.rmtree(repo_path)
        print(f'{repo_path} removed successfully.')
    else:
        print(f'Repository directory {repo_path} does not exist.')
else:
    print('REPO_NAME variable not found or is empty. Please ensure the repository name is set.')
# Out:
# Removing /content/csci739-project-mamba...
# /content/csci739-project-mamba removed successfully.

# %% [markdown]
# **Clone repo**

# %%
import os
import sys


# Construct the git clone command
clone_command = f"git clone "
if BRANCH_NAME:
    clone_command += f"--branch {BRANCH_NAME} "
clone_command += f"{GITHUB_REPO_URL} /content/{REPO_NAME}"

# Clone the repository
get_ipython().system(clone_command)

# Navigate into the cloned directory
# %cd /content/{REPO_NAME}

# Checkout a specific commit if provided
if COMMIT_HASH:
    print(f"Checking out commit: {COMMIT_HASH}")
    get_ipython().system(f"git checkout {COMMIT_HASH}")
else:
    if not BRANCH_NAME:
        print("Using the latest commit on the default branch.")
    else:
        print(f"Using the latest commit on branch: {BRANCH_NAME}")

# Navigate back to the content directory (or stay in the repo root if that's where the code is)
# %cd /content

# Add the repository (or its subdirectory) to sys.path
repo_path = f"/content/{REPO_NAME}"
if SUBDIRECTORY:
    repo_path = os.path.join(repo_path, SUBDIRECTORY)

if repo_path not in sys.path:
    sys.path.insert(0, repo_path)
    print(f"Added {repo_path} to sys.path")
else:
    print(f"{repo_path} is already in sys.path")

print("Current sys.path:")
for p in sys.path:
    print(p)
# Out:
# Cloning into '/content/csci739-project-mamba'...
# remote: Enumerating objects: 592, done.
# remote: Counting objects: 100% (248/248), done.
# remote: Compressing objects: 100% (181/181), done.
# remote: Total 592 (delta 126), reused 150 (delta 67), pack-reused 344 (from 1)
# Receiving objects: 100% (592/592), 4.85 MiB | 11.34 MiB/s, done.
# Resolving deltas: 100% (257/257), done.
# /content/csci739-project-mamba
# Using the latest commit on branch: experiments
# /content
# Added /content/csci739-project-mamba to sys.path
# Current sys.path:
# /content/csci739-project-mamba
# /content
# /env/python
# /usr/lib/python312.zip
# /usr/lib/python3.12
# /usr/lib/python3.12/lib-dynload
#
# /usr/local/lib/python3.12/dist-packages
# /usr/lib/python3/dist-packages
# /usr/local/lib/python3.12/dist-packages/IPython/extensions
# /root/.ipython

# %% [markdown]
# ### Set W&B API Key from Colab Secrets
#
# This cell will retrieve your Weights & Biases API key from Colab's 'Secrets' and set it as an environment variable, making it accessible to `os.environ.get()` within your `train.py` script.

# %% [markdown]
# set hf token

# %%
# # HF_TOKEN = userdata.get('HF_TOKEN')


# if HF_TOKEN:
#     os.environ['HF_TOKEN'] = HF_TOKEN
#     print("HF_TOKEN loaded from Colab secrets and set as environment variable.")
# else:
#     print("HF_TOKEN not found in Colab secrets. Please ensure it's set there.")

# import huggingface_hub
# huggingface_hub.login(token=os.environ['HF_TOKEN'], add_to_git_credential=False)

# %% [markdown]
# ### Mount drive for accessing data in Colab

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# Add path so imports work
import sys
sys.path.insert(0, "/content/drive/MyDrive/csci739_GenAI_topics/project_resources")
# Out:
# Mounted at /content/drive

# %%
blurp # force fail
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_17679/3689156905.py in <cell line: 0>()
# ----> 1 blurp # force fail
#
# NameError: name 'blurp' is not defined

# %% [markdown]
# ## Run in context learning expeirments
#
# ### SPecific model

# %%
import sys
sys.argv = [
    "icl_tasks.py",
    "--model_path",    "/content/drive/MyDrive/csci739_GenAI_topics/project_resources/mamba_simplestories_5m.pt",
    "--model_variant", "5m",
    "--tokenizer_name", "SimpleStories/SimpleStories-5M",
]

# %%
from icl_tasks import main
main()

# %% [markdown]
# ### All models

# %%
import sys
sys.path.insert(0, "csci739-project-mamba/experiments")

from experiment_pretrained_icl import run_experiments
run_experiments()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Running on device: cuda
#
# ============================================================
# Experiment: 5M_SimpleStories
#
#   Loading ssm from checkpoint: /content/drive/MyDrive/csci739_GenAI_topics/project_resources/mamba_simplestories_5m_final.pt
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:103: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# Evaluating ssm_5M_SimpleStories on ICL...
# WARNING: mapping present_simple_past_perfect has only 60 examples after filtering (110 before)
# WARNING: mapping singular_plural has only 14 examples after filtering (173 before)
# WARNING: mapping plural_singular has only 23 examples after filtering (172 before)
#
# ==================================================
# Running task 1/21: algorithmic_next_letter
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['n', 'l', 'i', 'g', 'n']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['z', 'v', 'o', 'y', 'w']
# Baseline Accuracy: 0.00  (2.7s)
# ICL Accuracy: 0.00  (1.3s)
#
# ==================================================
# Running task 2/21: algorithmic_prev_letter
# Sample predictions: ['.', '.', ',', '.', '.']
# Sample expected: ['m', 'k', 'h', 'f', 'm']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['y', 'u', 'n', 'x', 'v']
# Baseline Accuracy: 0.00  (2.4s)
# ICL Accuracy: 0.00  (1.2s)
#
# ==================================================
# Running task 3/21: algorithmic_list_first
# Sample predictions: ['!', '.', '.', '.', '.']
# Sample expected: ['i', 'p', 'w', 'r', 'y']
# Sample predictions: ['.', '.', '!', '.', '.']
# Sample expected: ['q', 'n', 'z', 'l', 'y']
# Baseline Accuracy: 0.00  (2.4s)
# ICL Accuracy: 0.00  (1.0s)
#
# ==================================================
# Running task 4/21: algorithmic_list_last
# Sample predictions: ['!', '.', '.', '.', '.']
# Sample expected: ['x', 'o', 'a', 'v', 'z']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['y', 'p', 's', 'u', 'f']
# Baseline Accuracy: 0.00  (2.4s)
# ICL Accuracy: 0.00  (1.0s)
#
# ==================================================
# Running task 5/21: algorithmic_list_min
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['3', '5', '0', '6', '9']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['3', '5', '3', '4', '2']
# Baseline Accuracy: 0.00  (2.4s)
# ICL Accuracy: 0.00  (1.1s)
#
# ==================================================
# Running task 6/21: algorithmic_list_max
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['9', '6', '8', '8', '9']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['9', '7', '9', '7', '9']
# Baseline Accuracy: 0.00  (2.4s)
# ICL Accuracy: 0.00  (1.1s)
#
# ==================================================
# Running task 7/21: algorithmic_list_length
# Sample predictions: [',', '.', '.', '.', '.']
# Sample expected: ['2', '2', '3', '1', '3']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['1', '3', '1', '1', '2']
# Baseline Accuracy: 0.00  (2.4s)
# ICL Accuracy: 0.00  (1.1s)
#
# ==================================================
# Running task 8/21: algorithmic_to_upper
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['M', 'K', 'H', 'F', 'M']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['B', 'E', 'T', 'H', 'X']
# Baseline Accuracy: 0.00  (2.4s)
# ICL Accuracy: 0.00  (1.2s)
#
# ==================================================
# Running task 9/21: algorithmic_to_lower
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['m', 'k', 'h', 'f', 'm']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['b', 'e', 't', 'h', 'x']
# Baseline Accuracy: 0.00  (2.4s)
# ICL Accuracy: 0.00  (1.2s)
#
# ==================================================
# Running task 10/21: algorithmic_char_to_int
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['7', '6', '4', '3', '7']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['1', '4', '7', '9', '1']
# Baseline Accuracy: 0.00  (2.4s)
# ICL Accuracy: 0.00  (1.2s)
#
# ==================================================
# Running task 11/21: algorithmic_int_to_char
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['g', 'f', 'd', 'c', 'g']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['a', 'd', 'g', 'i', 'a']
# Baseline Accuracy: 0.00  (2.4s)
# ICL Accuracy: 0.00  (1.2s)
#
# ==================================================
# Running task 12/21: linguistic_present_simple_gerund
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: [' passing', ' living', ' growing', ' falling', ' picking']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: [' rising', ' sparkling', ' wandering', ' staring', ' rushing']
# Baseline Accuracy: 0.00  (2.4s)
# ICL Accuracy: 0.00  (1.2s)
#
# ==================================================
# Running task 13/21: linguistic_present_simple_past_simple
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: [' raced', ' noticed', ' headed', ' fell', ' read']
# Sample predictions: ['.', '.', '.', '.', ',']
# Sample expected: [' put', ' failed', ' held', ' stepped', ' sensed']
# Baseline Accuracy: 0.00  (2.4s)
# ICL Accuracy: 0.00  (1.2s)
#
# ==================================================
# Running task 14/21: linguistic_present_simple_past_perfect
# WARNING: mapping present_simple_past_perfect has only 60 examples after filtering (110 before)
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: [' heard', ' gone', ' fallen', ' cost', ' worn']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: [' found', ' known', ' sat', ' spun', ' worn']
# Baseline Accuracy: 0.00  (2.4s)
# ICL Accuracy: 0.00  (1.2s)
#
# ==================================================
# Running task 15/21: linguistic_singular_plural
# WARNING: mapping singular_plural has only 14 examples after filtering (173 before)
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: [' heroes', ' feet', ' echoes', ' deer', ' heroes']
# Sample predictions: ['.', ',', '.', '.', '.']
# Sample expected: [' feet', ' means', ' heroes', ' feet', ' châteaus']
# Baseline Accuracy: 0.00  (2.4s)
# ICL Accuracy: 0.00  (1.2s)
#
# ==================================================
# Running task 16/21: linguistic_plural_singular
# WARNING: mapping plural_singular has only 23 examples after filtering (172 before)
# Sample predictions: ['.', ',', '.', '.', '.']
# Sample expected: [' man', ' life', ' half', ' fish', ' man']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: [' mouse', ' person', ' shelf', ' woman', ' deer']
# Baseline Accuracy: 0.00  (2.4s)
# ICL Accuracy: 0.00  (1.2s)
#
# ==================================================
# Running task 17/21: linguistic_antonyms
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: [' follow', ' cold', ' sick', ' bright', ' right']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: [' warm', ' down', ' smooth', ' narrow', ' narrow']
# Baseline Accuracy: 0.00  (2.4s)
# ICL Accuracy: 0.00  (1.2s)
#
# ==================================================
# Running task 18/21: knowledge_country_capital
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['Venice', 'Berlin', 'Paris', 'Berlin', 'Beijing']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['Athens', 'Mumbai', 'Dublin', 'Ankara', 'London']
# Baseline Accuracy: 0.00  (2.4s)
# ICL Accuracy: 0.00  (1.3s)
#
# ==================================================
# Running task 19/21: knowledge_person_language
# Sample predictions: ['.', '.', '.', '.', '!']
# Sample expected: ['Ukrainian', 'English', 'Dutch', 'French', 'Italian']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['Russian', 'French', 'Dutch', 'Spanish', 'Spanish']
# Baseline Accuracy: 0.00  (2.4s)
# ICL Accuracy: 0.00  (1.3s)
#
# ==================================================
# Running task 20/21: knowledge_location_continent
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['Asia', 'Antarctica', 'Antarctica', 'Africa', 'Antarctica']
# Sample predictions: [',', '.', '.', ',', '.']
# Sample expected: ['Asia', 'Africa', 'Antarctica', 'Antarctica', 'Antarctica']
# Baseline Accuracy: 0.00  (2.4s)
# ICL Accuracy: 0.00  (1.2s)
#
# ==================================================
# Running task 21/21: knowledge_location_religion
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['Muslim', 'Jewish', 'Jewish', 'Christian', 'Jewish']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['Muslim', 'Christian', 'Christian', 'Muslim', 'Muslim']
# Baseline Accuracy: 0.00  (2.4s)
# ICL Accuracy: 0.00  (1.4s)
#
#   Loading transformer from HuggingFace: SimpleStories/SimpleStories-5M
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights:   0%|          | 0/56 [00:00<?, ?it/s]
# Evaluating transformer_5M_SimpleStories on ICL...
# WARNING: mapping present_simple_past_perfect has only 60 examples after filtering (110 before)
# WARNING: mapping singular_plural has only 14 examples after filtering (173 before)
# WARNING: mapping plural_singular has only 23 examples after filtering (172 before)
#
# ==================================================
# Running task 1/21: algorithmic_next_letter
# Sample predictions: ['!', 'together', '!', '!', '!']
# Sample expected: ['n', 'l', 'i', 'g', 'n']
# Sample predictions: ['.', '!', '!', '!', '.']
# Sample expected: ['z', 'v', 'o', 'y', 'w']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.5s)
#
# ==================================================
# Running task 2/21: algorithmic_prev_letter
# Sample predictions: ['with', ',', '?', '?', 'with']
# Sample expected: ['m', 'k', 'h', 'f', 'm']
# Sample predictions: ['!', '!', '.', '!', '.']
# Sample expected: ['y', 'u', 'n', 'x', 'v']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.5s)
#
# ==================================================
# Running task 3/21: algorithmic_list_first
# Sample predictions: ['!', ',', '##ing', ',', '!']
# Sample expected: ['i', 'p', 'w', 'r', 'y']
# Sample predictions: ['!', '!', '!', '!', ',']
# Sample expected: ['q', 'n', 'z', 'l', 'y']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.5s)
#
# ==================================================
# Running task 4/21: algorithmic_list_last
# Sample predictions: ['!', ',', '##ing', ',', '!']
# Sample expected: ['x', 'o', 'a', 'v', 'z']
# Sample predictions: ['!', '!', '!', '!', ',']
# Sample expected: ['y', 'p', 's', 'u', 'f']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.5s)
#
# ==================================================
# Running task 5/21: algorithmic_list_min
# Sample predictions: ['!', '!', '!', '##s', '##s']
# Sample expected: ['3', '5', '0', '6', '9']
# Sample predictions: ['!', '!', '!', '!', '!']
# Sample expected: ['3', '5', '3', '4', '2']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.5s)
#
# ==================================================
# Running task 6/21: algorithmic_list_max
# Sample predictions: ['!', '!', '!', '##s', '##s']
# Sample expected: ['9', '6', '8', '8', '9']
# Sample predictions: ['!', '!', '!', '!', '!']
# Sample expected: ['9', '7', '9', '7', '9']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.5s)
#
# ==================================================
# Running task 7/21: algorithmic_list_length
# Sample predictions: ['!', ',', '!', '?', '##ing']
# Sample expected: ['2', '2', '3', '1', '3']
# Sample predictions: ['!', '!', '!', '!', '!']
# Sample expected: ['1', '3', '1', '1', '2']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.5s)
#
# ==================================================
# Running task 8/21: algorithmic_to_upper
# Sample predictions: ['!', 'together', '!', '!', '!']
# Sample expected: ['M', 'K', 'H', 'F', 'M']
# Sample predictions: ['!', '!', '!', '!', '!']
# Sample expected: ['B', 'E', 'T', 'H', 'X']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.5s)
#
# ==================================================
# Running task 9/21: algorithmic_to_lower
# Sample predictions: ['!', 'together', '!', '!', '!']
# Sample expected: ['m', 'k', 'h', 'f', 'm']
# Sample predictions: ['!', '!', '!', '!', '!']
# Sample expected: ['b', 'e', 't', 'h', 'x']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.5s)
#
# ==================================================
# Running task 10/21: algorithmic_char_to_int
# Sample predictions: ['?', '!', 'on', 'with', '?']
# Sample expected: ['7', '6', '4', '3', '7']
# Sample predictions: ['!', '!', '!', '!', '!']
# Sample expected: ['1', '4', '7', '9', '1']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.5s)
#
# ==================================================
# Running task 11/21: algorithmic_int_to_char
# Sample predictions: ['!', '##ing', '!', ',', '!']
# Sample expected: ['g', 'f', 'd', 'c', 'g']
# Sample predictions: ['!', '!', '!', '!', '!']
# Sample expected: ['a', 'd', 'g', 'i', 'a']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.5s)
#
# ==================================================
# Running task 12/21: linguistic_present_simple_gerund
# Sample predictions: ['and', ',', ',', '##s', 'it']
# Sample expected: [' passing', ' living', ' growing', ' falling', ' picking']
# Sample predictions: [',', '.', ',', '!', 'to']
# Sample expected: [' rising', ' sparkling', ' wandering', ' staring', ' rushing']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.5s)
#
# ==================================================
# Running task 13/21: linguistic_present_simple_past_simple
# Sample predictions: ['.', 'on', '.', '##s', '##s']
# Sample expected: [' raced', ' noticed', ' headed', ' fell', ' read']
# Sample predictions: [',', '.', 'and', ',', '##s']
# Sample expected: [' put', ' failed', ' held', ' stepped', ' sensed']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.5s)
#
# ==================================================
# Running task 14/21: linguistic_present_simple_past_perfect
# WARNING: mapping present_simple_past_perfect has only 60 examples after filtering (110 before)
# Sample predictions: ['##s', '.', '##s', 'was', '##ed']
# Sample expected: [' heard', ' gone', ' fallen', ' cost', ' worn']
# Sample predictions: ['on', 'on', 'on', ',', 'with']
# Sample expected: [' found', ' known', ' sat', ' spun', ' worn']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.5s)
#
# ==================================================
# Running task 15/21: linguistic_singular_plural
# WARNING: mapping singular_plural has only 14 examples after filtering (173 before)
# Sample predictions: ['!', '.', '##s', ',', '!']
# Sample expected: [' heroes', ' feet', ' echoes', ' deer', ' heroes']
# Sample predictions: [',', '##s', ',', '.', '##s']
# Sample expected: [' feet', ' means', ' heroes', ' feet', ' châteaus']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.5s)
#
# ==================================================
# Running task 16/21: linguistic_plural_singular
# WARNING: mapping plural_singular has only 23 examples after filtering (172 before)
# Sample predictions: [',', '##s', ',', '!', ',']
# Sample expected: [' man', ' life', ' half', ' fish', ' man']
# Sample predictions: [',', ',', '##s', '.', ',']
# Sample expected: [' mouse', ' person', ' shelf', ' woman', ' deer']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.5s)
#
# ==================================================
# Running task 17/21: linguistic_antonyms
# Sample predictions: ['to', 'air', 'with', '.', '##s']
# Sample expected: [' follow', ' cold', ' sick', ' bright', ' right']
# Sample predictions: ['.', '.', '##s', '.', '.']
# Sample expected: [' warm', ' down', ' smooth', ' narrow', ' narrow']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.5s)
#
# ==================================================
# Running task 18/21: knowledge_country_capital
# Sample predictions: ['##ing', ',', '##s', '!', ',']
# Sample expected: ['Venice', 'Berlin', 'Paris', 'Berlin', 'Beijing']
# Sample predictions: [',', ',', '!', ',', ',']
# Sample expected: ['Athens', 'Mumbai', 'Dublin', 'Ankara', 'London']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.5s)
#
# ==================================================
# Running task 19/21: knowledge_person_language
# Sample predictions: [',', '!', ',', '?', '!']
# Sample expected: ['Ukrainian', 'English', 'Dutch', 'French', 'Italian']
# Sample predictions: [',', ',', '.', '!', ',']
# Sample expected: ['Russian', 'French', 'Dutch', 'Spanish', 'Spanish']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.5s)
#
# ==================================================
# Running task 20/21: knowledge_location_continent
# Sample predictions: ['##s', '!', ',', ',', '?']
# Sample expected: ['Asia', 'Antarctica', 'Antarctica', 'Africa', 'Antarctica']
# Sample predictions: [',', ',', ',', ',', '##ing']
# Sample expected: ['Asia', 'Africa', 'Antarctica', 'Antarctica', 'Antarctica']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.5s)
#
# ==================================================
# Running task 21/21: knowledge_location_religion
# Sample predictions: ['!', '.', ',', 'on', ',']
# Sample expected: ['Muslim', 'Jewish', 'Jewish', 'Christian', 'Jewish']
# Sample predictions: ['!', ',', '!', '!', ',']
# Sample expected: ['Muslim', 'Christian', 'Christian', 'Muslim', 'Muslim']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.5s)
#
# ============================================================
# Experiment: ~130M_pile
#
#   Loading ssm from HuggingFace: state-spaces/mamba-130m-hf
# The fast path is not available because one of `(selective_state_update, selective_scan_fn, causal_conv1d_fn, causal_conv1d_update, mamba_inner_fn)` is None. Falling back to the sequential implementation of Mamba, as use_mambapy is set to False. To install follow https://github.com/state-spaces/mamba/#installation for mamba-ssm and install the kernels library using `pip install kernels` or https://github.com/Dao-AILab/causal-conv1d for causal-conv1d. For the mamba.py backend, follow https://github.com/alxndrTL/mamba.py.
# Loading weights:   0%|          | 0/242 [00:00<?, ?it/s]
# MambaForCausalLM LOAD REPORT from: state-spaces/mamba-130m-hf
# Key            | Status  |
# ---------------+---------+-
# lm_head.weight | MISSING |
#
# Notes:
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Evaluating ssm_~130M_pile on ICL...
#
# ==================================================
# Running task 1/21: algorithmic_next_letter
# Sample predictions: ['m', 'm', 'h', 'get', 'm']
# Sample expected: ['n', 'l', 'i', 'g', 'n']
# Sample predictions: ['e', 'v', 'p', 'y', 'x']
# Sample expected: ['z', 'v', 'o', 'y', 'w']
# Baseline Accuracy: 0.00  (3.2s)
# ICL Accuracy: 0.26  (3.8s)
#
# ==================================================
# Running task 2/21: algorithmic_prev_letter
# Sample predictions: ['next', 'l', 'm', 'm', 'next']
# Sample expected: ['m', 'k', 'h', 'f', 'm']
# Sample predictions: ['w', 't', 'r', 'a', 'r']
# Sample expected: ['y', 'u', 'n', 'x', 'v']
# Baseline Accuracy: 0.00  (3.1s)
# ICL Accuracy: 0.02  (3.9s)
#
# ==================================================
# Running task 3/21: algorithmic_list_first
# Sample predictions: ['x', 'p', 'w', 'r', 'y']
# Sample expected: ['i', 'p', 'w', 'r', 'y']
# Sample predictions: ['h', 't', 'h', 'l', 'y']
# Sample expected: ['q', 'n', 'z', 'l', 'y']
# Baseline Accuracy: 0.58  (4.0s)
# ICL Accuracy: 0.74  (6.4s)
#
# ==================================================
# Running task 4/21: algorithmic_list_last
# Sample predictions: ['x', 'p', 'w', 'r', 'y']
# Sample expected: ['x', 'o', 'a', 'v', 'z']
# Sample predictions: ['y', 'p', 's', 'u', 'f']
# Sample expected: ['y', 'p', 's', 'u', 'f']
# Baseline Accuracy: 0.12  (4.0s)
# ICL Accuracy: 0.98  (6.3s)
#
# ==================================================
# Running task 5/21: algorithmic_list_min
# Sample predictions: ['1', '6', '0', '6', '9']
# Sample expected: ['3', '5', '0', '6', '9']
# Sample predictions: ['3', '5', '1', '4', '1']
# Sample expected: ['3', '5', '3', '4', '2']
# Baseline Accuracy: 0.55  (4.0s)
# ICL Accuracy: 0.58  (6.4s)
#
# ==================================================
# Running task 6/21: algorithmic_list_max
# Sample predictions: ['1', '6', '0', '6', '9']
# Sample expected: ['9', '6', '8', '8', '9']
# Sample predictions: ['9', '5', '9', '7', '9']
# Sample expected: ['9', '7', '9', '7', '9']
# Baseline Accuracy: 0.16  (4.0s)
# ICL Accuracy: 0.64  (6.4s)
#
# ==================================================
# Running task 7/21: algorithmic_list_length
# Sample predictions: ['x', 'p', 'x', 'name', 'x']
# Sample expected: ['2', '2', '3', '1', '3']
# Sample predictions: ['3', '1', '1', '1', '2']
# Sample expected: ['1', '3', '1', '1', '2']
# Baseline Accuracy: 0.00  (3.6s)
# ICL Accuracy: 0.50  (5.1s)
#
# ==================================================
# Running task 8/21: algorithmic_to_upper
# Sample predictions: ['m', 'm', 'h', 'get', 'm']
# Sample expected: ['M', 'K', 'H', 'F', 'M']
# Sample predictions: ['B', 'E', 'T', 'H', 'X']
# Sample expected: ['B', 'E', 'T', 'H', 'X']
# Baseline Accuracy: 0.00  (3.1s)
# ICL Accuracy: 0.98  (3.8s)
#
# ==================================================
# Running task 9/21: algorithmic_to_lower
# Sample predictions: ['m', 'm', 'm', 'm', 'm']
# Sample expected: ['m', 'k', 'h', 'f', 'm']
# Sample predictions: ['b', 'e', 't', 'h', 'x']
# Sample expected: ['b', 'e', 't', 'h', 'x']
# Baseline Accuracy: 0.16  (3.1s)
# ICL Accuracy: 1.00  (3.8s)
#
# ==================================================
# Running task 10/21: algorithmic_char_to_int
# Sample predictions: ['m', 'get', 'd', 'c', 'm']
# Sample expected: ['7', '6', '4', '3', '7']
# Sample predictions: ['1', '3', '10', '6', '9']
# Sample expected: ['1', '4', '7', '9', '1']
# Baseline Accuracy: 0.00  (3.1s)
# ICL Accuracy: 0.08  (3.8s)
#
# ==================================================
# Running task 11/21: algorithmic_int_to_char
# Sample predictions: ['m', '', 'get', 'get', 'm']
# Sample expected: ['g', 'f', 'd', 'c', 'g']
# Sample predictions: ['a', 'c', 'j', 'a', 'i']
# Sample expected: ['a', 'd', 'g', 'i', 'a']
# Baseline Accuracy: 0.00  (3.1s)
# ICL Accuracy: 0.18  (3.8s)
#
# ==================================================
# Running task 12/21: linguistic_present_simple_gerund
# Sample predictions: ['get', 'get', 'get', 'get', 'get']
# Sample expected: [' quoting', ' offering', ' handing', ' eating', ' reaching']
# Sample predictions: [' back', ' healing', ' growing', ' switching', ' examine']
# Sample expected: [' backing', ' healing', ' growing', ' switching', ' examining']
# Baseline Accuracy: 0.00  (3.1s)
# ICL Accuracy: 0.56  (3.8s)
#
# ==================================================
# Running task 13/21: linguistic_present_simple_past_simple
# Sample predictions: ['name', 'lock', 'get', 'draw', 'set']
# Sample expected: [' peeled', ' locked', ' forgot', ' drew', ' picked']
# Sample predictions: [' part', ' caught', ' flooded', ' stretched', ' cost']
# Sample expected: [' parted', ' caught', ' flooded', ' stretched', ' cost']
# Baseline Accuracy: 0.00  (3.1s)
# ICL Accuracy: 0.52  (3.8s)
#
# ==================================================
# Running task 14/21: linguistic_present_simple_past_perfect
# Sample predictions: ['get', 'get', 'fly', 'draw', 'value']
# Sample expected: [' made', ' known', ' flown', ' drawn', ' meant']
# Sample predictions: [' let', ' grown', ' kept', ' fought', ' drove']
# Sample expected: [' let', ' grown', ' kept', ' fought', ' driven']
# Baseline Accuracy: 0.02  (3.1s)
# ICL Accuracy: 0.54  (3.8s)
#
# ==================================================
# Running task 15/21: linguistic_singular_plural
# Sample predictions: ['name', 'mouse', 'get', 'fish', '']
# Sample expected: [' people', ' mice', ' hypotheses', ' fish', ' phenomena']
# Sample predictions: [' analysis', ' index', ' hypotheses', ' that', ' echo']
# Sample expected: [' analyses', ' indices', ' hypotheses', ' those', ' echoes']
# Baseline Accuracy: 0.07  (3.1s)
# ICL Accuracy: 0.48  (3.8s)
#
# ==================================================
# Running task 16/21: linguistic_plural_singular
# Sample predictions: ['m', 'next', 'feet', '', 'media']
# Sample expected: [' measles', ' leaf', ' foot', ' deer', ' medium']
# Sample predictions: [' vertices', ' swine', ' emph', ' vort', ' series']
# Sample expected: [' vertex', ' swine', ' emphasis', ' vortex', ' series']
# Baseline Accuracy: 0.06  (3.2s)
# ICL Accuracy: 0.38  (4.0s)
#
# ==================================================
# Running task 17/21: linguistic_antonyms
# Sample predictions: ['', 'low', 'get', 'error', 'get']
# Sample expected: [' even', ' quiet', ' stop', ' succeed', ' refuse']
# Sample predictions: [' odd', ' fail', ' guilty', ' safe', ' quiet']
# Sample expected: [' even', ' succeed', ' innocent', ' dangerous', ' loud']
# Baseline Accuracy: 0.11  (3.1s)
# ICL Accuracy: 0.34  (3.8s)
#
# ==================================================
# Running task 18/21: knowledge_country_capital
# Sample predictions: ['', 'Germany', 'France', 'Germany', 'Q']
# Sample expected: ['Venice', 'Berlin', 'Paris', 'Berlin', 'Beijing']
# Sample predictions: ['Pr', 'Mad', 'London', 'An', 'K']
# Sample expected: ['Athens', 'Mumbai', 'Dublin', 'Ankara', 'London']
# Baseline Accuracy: 0.04  (3.7s)
# ICL Accuracy: 0.28  (6.2s)
#
# ==================================================
# Running task 19/21: knowledge_person_language
# Sample predictions: [' I', 'G', '', 'get', ' "']
# Sample expected: ['Ukrainian', 'English', 'Dutch', 'French', 'Italian']
# Sample predictions: ['Russian', 'French', 'Dutch', 'Spanish', 'Spanish']
# Sample expected: ['Russian', 'French', 'Dutch', 'Spanish', 'Spanish']
# Baseline Accuracy: 0.01  (4.1s)
# ICL Accuracy: 0.62  (6.5s)
#
# ==================================================
# Running task 20/21: knowledge_location_continent
# Sample predictions: ['', '', '', 'Ch', 'South']
# Sample expected: ['Asia', 'Antarctica', 'Antarctica', 'Africa', 'Antarctica']
# Sample predictions: ['An', 'An', 'Europe', 'An', 'An']
# Sample expected: ['Asia', 'Africa', 'Antarctica', 'Antarctica', 'Antarctica']
# Baseline Accuracy: 0.02  (3.8s)
# ICL Accuracy: 0.60  (6.4s)
#
# ==================================================
# Running task 21/21: knowledge_location_religion
# Sample predictions: ['', 'get', '', '', '']
# Sample expected: ['Muslim', 'Jewish', 'Jewish', 'Christian', 'Jewish']
# Sample predictions: ['Muslim', 'Muslim', 'Muslim', 'Muslim', 'Christian']
# Sample expected: ['Muslim', 'Christian', 'Christian', 'Muslim', 'Muslim']
# Baseline Accuracy: 0.03  (4.1s)
# ICL Accuracy: 0.70  (6.6s)
#
#   Loading transformer from HuggingFace: EleutherAI/pythia-160m
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Evaluating transformer_~130M_pile on ICL...
#
# ==================================================
# Running task 1/21: algorithmic_next_letter
# Sample predictions: ['m', 'm', 'get', 'get', 'm']
# Sample expected: ['n', 'l', 'i', 'g', 'n']
# Sample predictions: ['y', 'u', 'n', 'o', 'i']
# Sample expected: ['z', 'v', 'o', 'y', 'w']
# Baseline Accuracy: 0.01  (1.1s)
# ICL Accuracy: 0.04  (0.6s)
#
# ==================================================
# Running task 2/21: algorithmic_prev_letter
# Sample predictions: ['name', 'm', 'i', 'get', 'name']
# Sample expected: ['m', 'k', 'h', 'f', 'm']
# Sample predictions: ['w', 't', 'l', 'c', 'h']
# Sample expected: ['y', 'u', 'n', 'x', 'v']
# Baseline Accuracy: 0.00  (1.1s)
# ICL Accuracy: 0.00  (0.6s)
#
# ==================================================
# Running task 3/21: algorithmic_list_first
# Sample predictions: ['i', 'p', 'b', 'i', 'y']
# Sample expected: ['i', 'p', 'w', 'r', 'y']
# Sample predictions: ['q', 't', 'h', 'l', 'y']
# Sample expected: ['q', 'n', 'z', 'l', 'y']
# Baseline Accuracy: 0.27  (1.1s)
# ICL Accuracy: 0.82  (0.6s)
#
# ==================================================
# Running task 4/21: algorithmic_list_last
# Sample predictions: ['i', 'p', 'b', 'i', 'y']
# Sample expected: ['x', 'o', 'a', 'v', 'z']
# Sample predictions: ['y', 'r', 'k', 'l', 'y']
# Sample expected: ['y', 'p', 's', 'u', 'f']
# Baseline Accuracy: 0.20  (1.1s)
# ICL Accuracy: 0.46  (0.6s)
#
# ==================================================
# Running task 5/21: algorithmic_list_min
# Sample predictions: ['0', '0', '0', 'b', '0']
# Sample expected: ['3', '5', '0', '6', '9']
# Sample predictions: ['3', '5', '1', '7', '9']
# Sample expected: ['3', '5', '3', '4', '2']
# Baseline Accuracy: 0.29  (1.1s)
# ICL Accuracy: 0.44  (0.6s)
#
# ==================================================
# Running task 6/21: algorithmic_list_max
# Sample predictions: ['0', '0', '0', 'b', '0']
# Sample expected: ['9', '6', '8', '8', '9']
# Sample predictions: ['6', '5', '9', '4', '9']
# Sample expected: ['9', '7', '9', '7', '9']
# Baseline Accuracy: 0.00  (1.1s)
# ICL Accuracy: 0.50  (0.6s)
#
# ==================================================
# Running task 7/21: algorithmic_list_length
# Sample predictions: ['i', 'p', 'i', 'm', 'y']
# Sample expected: ['2', '2', '3', '1', '3']
# Sample predictions: ['3', '2', '2', '1', '1']
# Sample expected: ['1', '3', '1', '1', '2']
# Baseline Accuracy: 0.00  (1.1s)
# ICL Accuracy: 0.34  (0.6s)
#
# ==================================================
# Running task 8/21: algorithmic_to_upper
# Sample predictions: ['m', 'm', 'get', 'get', 'm']
# Sample expected: ['M', 'K', 'H', 'F', 'M']
# Sample predictions: ['B', 'E', 'T', 'H', 'I']
# Sample expected: ['B', 'E', 'T', 'H', 'X']
# Baseline Accuracy: 0.00  (1.1s)
# ICL Accuracy: 0.54  (0.6s)
#
# ==================================================
# Running task 9/21: algorithmic_to_lower
# Sample predictions: ['get', 'get', 'get', 'get', 'get']
# Sample expected: ['m', 'k', 'h', 'f', 'm']
# Sample predictions: ['x', 'c', 't', 'w', 'i']
# Sample expected: ['b', 'e', 't', 'h', 'x']
# Baseline Accuracy: 0.00  (1.1s)
# ICL Accuracy: 0.58  (0.6s)
#
# ==================================================
# Running task 10/21: algorithmic_char_to_int
# Sample predictions: ['get', 'get', 'm', 'm', 'get']
# Sample expected: ['7', '6', '4', '3', '7']
# Sample predictions: ['1', '3', '10', '7', '9']
# Sample expected: ['1', '4', '7', '9', '1']
# Baseline Accuracy: 0.00  (1.1s)
# ICL Accuracy: 0.10  (0.6s)
#
# ==================================================
# Running task 11/21: algorithmic_int_to_char
# Sample predictions: ['get', 'get', 'get', 'get', 'get']
# Sample expected: ['g', 'f', 'd', 'c', 'g']
# Sample predictions: ['d', 'c', 'j', 'f', 'i']
# Sample expected: ['a', 'd', 'g', 'i', 'a']
# Baseline Accuracy: 0.00  (1.1s)
# ICL Accuracy: 0.06  (0.6s)
#
# ==================================================
# Running task 12/21: linguistic_present_simple_gerund
# Sample predictions: ['name', 'get', 'get', 'get', 'next']
# Sample expected: [' quoting', ' offering', ' handing', ' eating', ' reaching']
# Sample predictions: [' branding', ' heal', ' grow', ' switching', ' examining']
# Sample expected: [' backing', ' healing', ' growing', ' switching', ' examining']
# Baseline Accuracy: 0.00  (1.1s)
# ICL Accuracy: 0.28  (0.6s)
#
# ==================================================
# Running task 13/21: linguistic_present_simple_past_simple
# Sample predictions: ['get', 'type', 'get', 'get', 'name']
# Sample expected: [' peeled', ' locked', ' forgot', ' drew', ' picked']
# Sample predictions: [' part', ' catch', ' cried', ' listed', ' cost']
# Sample expected: [' parted', ' caught', ' flooded', ' stretched', ' cost']
# Baseline Accuracy: 0.00  (1.1s)
# ICL Accuracy: 0.26  (0.6s)
#
# ==================================================
# Running task 14/21: linguistic_present_simple_past_perfect
# Sample predictions: ['type', 'name', 'get', 'get', 'name']
# Sample expected: [' made', ' known', ' flown', ' drawn', ' meant']
# Sample predictions: [' let', ' grow', ' keep', ' fight', ' drive']
# Sample expected: [' let', ' grown', ' kept', ' fought', ' driven']
# Baseline Accuracy: 0.00  (1.1s)
# ICL Accuracy: 0.26  (0.6s)
#
# ==================================================
# Running task 15/21: linguistic_singular_plural
# Sample predictions: ['name', 'get', '', 'get', 'get']
# Sample expected: [' people', ' mice', ' hypotheses', ' fish', ' phenomena']
# Sample predictions: [' analysis', ' index', ' hypothesis', ' focus', ' echo']
# Sample expected: [' analyses', ' indices', ' hypotheses', ' those', ' echoes']
# Baseline Accuracy: 0.00  (1.1s)
# ICL Accuracy: 0.40  (0.6s)
#
# ==================================================
# Running task 16/21: linguistic_plural_singular
# Sample predictions: ['get', 'next', 'get', 'get', 'get']
# Sample expected: [' measles', ' leaf', ' foot', ' deer', ' medium']
# Sample predictions: [' vertices', ' swine', ' emph', ' vort', ' series']
# Sample expected: [' vertex', ' swine', ' emphasis', ' vortex', ' series']
# Baseline Accuracy: 0.00  (1.1s)
# ICL Accuracy: 0.42  (0.6s)
#
# ==================================================
# Running task 17/21: linguistic_antonyms
# Sample predictions: ['', '', 'get', 'type', 'get']
# Sample expected: [' even', ' quiet', ' stop', ' succeed', ' refuse']
# Sample predictions: [' loose', ' fail', ' guilty', ' accept', ' quiet']
# Sample expected: [' even', ' succeed', ' innocent', ' dangerous', ' loud']
# Baseline Accuracy: 0.00  (1.1s)
# ICL Accuracy: 0.16  (0.6s)
#
# ==================================================
# Running task 18/21: knowledge_country_capital
# Sample predictions: ['', '', '', '', '']
# Sample expected: ['Venice', 'Berlin', 'Paris', 'Berlin', 'Beijing']
# Sample predictions: ['Pr', 'M', 'S', 'An', 'B']
# Sample expected: ['Athens', 'Mumbai', 'Dublin', 'Ankara', 'London']
# Baseline Accuracy: 0.00  (1.1s)
# ICL Accuracy: 0.22  (0.6s)
#
# ==================================================
# Running task 19/21: knowledge_person_language
# Sample predictions: ['get', '', '', 'get', '']
# Sample expected: ['Ukrainian', 'English', 'Dutch', 'French', 'Italian']
# Sample predictions: ['Swed', 'French', 'Dutch', 'Spanish', 'Spanish']
# Sample expected: ['Russian', 'French', 'Dutch', 'Spanish', 'Spanish']
# Baseline Accuracy: 0.00  (1.1s)
# ICL Accuracy: 0.40  (0.6s)
#
# ==================================================
# Running task 20/21: knowledge_location_continent
# Sample predictions: ['', '', '', '', '']
# Sample expected: ['Asia', 'Antarctica', 'Antarctica', 'Africa', 'Antarctica']
# Sample predictions: ['An', 'Europe', 'Europe', 'An', 'Europe']
# Sample expected: ['Asia', 'Africa', 'Antarctica', 'Antarctica', 'Antarctica']
# Baseline Accuracy: 0.00  (1.1s)
# ICL Accuracy: 0.56  (0.6s)
#
# ==================================================
# Running task 21/21: knowledge_location_religion
# Sample predictions: ['', 'm', '', '', '']
# Sample expected: ['Muslim', 'Jewish', 'Jewish', 'Christian', 'Jewish']
# Sample predictions: ['Muslim', 'Muslim', 'Muslim', 'Muslim', 'Muslim']
# Sample expected: ['Muslim', 'Christian', 'Christian', 'Muslim', 'Muslim']
# Baseline Accuracy: 0.00  (1.1s)
# ICL Accuracy: 0.52  (0.6s)
#
# ============================================================
# Experiment: ~370M_pile
#
#   Loading ssm from HuggingFace: state-spaces/mamba-370m-hf
# Loading weights:   0%|          | 0/482 [00:00<?, ?it/s]
# MambaForCausalLM LOAD REPORT from: state-spaces/mamba-370m-hf
# Key            | Status  |
# ---------------+---------+-
# lm_head.weight | MISSING |
#
# Notes:
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Evaluating ssm_~370M_pile on ICL...
#
# ==================================================
# Running task 1/21: algorithmic_next_letter
# Sample predictions: ['m', 'state', 'h', 'get', 'm']
# Sample expected: ['n', 'l', 'i', 'g', 'n']
# Sample predictions: ['z', 'v', 's', 'e', 'j']
# Sample expected: ['z', 'v', 'o', 'y', 'w']
# Baseline Accuracy: 0.00  (6.2s)
# ICL Accuracy: 0.64  (7.6s)
#
# ==================================================
# Running task 2/21: algorithmic_prev_letter
# Sample predictions: ['get', 'get', 'get', 'get', 'get']
# Sample expected: ['m', 'k', 'h', 'f', 'm']
# Sample predictions: ['d', 'p', 's', 'm', 'h']
# Sample expected: ['y', 'u', 'n', 'x', 'v']
# Baseline Accuracy: 0.00  (6.2s)
# ICL Accuracy: 0.04  (7.6s)
#
# ==================================================
# Running task 3/21: algorithmic_list_first
# Sample predictions: ['x', 'p', 'w', 'r', 'y']
# Sample expected: ['i', 'p', 'w', 'r', 'y']
# Sample predictions: ['q', 'n', 'z', 'l', 'y']
# Sample expected: ['q', 'n', 'z', 'l', 'y']
# Baseline Accuracy: 0.51  (7.8s)
# ICL Accuracy: 0.96  (12.7s)
#
# ==================================================
# Running task 4/21: algorithmic_list_last
# Sample predictions: ['x', 'p', 'w', 'r', 'y']
# Sample expected: ['x', 'o', 'a', 'v', 'z']
# Sample predictions: ['y', 'p', 's', 'u', 'f']
# Sample expected: ['y', 'p', 's', 'u', 'f']
# Baseline Accuracy: 0.11  (7.8s)
# ICL Accuracy: 0.96  (12.7s)
#
# ==================================================
# Running task 5/21: algorithmic_list_min
# Sample predictions: ['3', '6', '0', '6', '9']
# Sample expected: ['3', '5', '0', '6', '9']
# Sample predictions: ['3', '5', '3', '7', '9']
# Sample expected: ['3', '5', '3', '4', '2']
# Baseline Accuracy: 0.36  (7.9s)
# ICL Accuracy: 0.64  (12.6s)
#
# ==================================================
# Running task 6/21: algorithmic_list_max
# Sample predictions: ['3', '6', '0', '6', '9']
# Sample expected: ['9', '6', '8', '8', '9']
# Sample predictions: ['9', '5', '7', '7', '2']
# Sample expected: ['9', '7', '9', '7', '9']
# Baseline Accuracy: 0.19  (7.8s)
# ICL Accuracy: 0.64  (12.8s)
#
# ==================================================
# Running task 7/21: algorithmic_list_length
# Sample predictions: ['i', 'p', 'h', 'u', 'z']
# Sample expected: ['2', '2', '3', '1', '3']
# Sample predictions: ['3', '2', '1', '2', '2']
# Sample expected: ['1', '3', '1', '1', '2']
# Baseline Accuracy: 0.00  (7.1s)
# ICL Accuracy: 0.52  (10.3s)
#
# ==================================================
# Running task 8/21: algorithmic_to_upper
# Sample predictions: ['m', 'state', 'h', 'get', 'm']
# Sample expected: ['M', 'K', 'H', 'F', 'M']
# Sample predictions: ['B', 'E', 'T', 'H', 'X']
# Sample expected: ['B', 'E', 'T', 'H', 'X']
# Baseline Accuracy: 0.00  (6.2s)
# ICL Accuracy: 1.00  (7.5s)
#
# ==================================================
# Running task 9/21: algorithmic_to_lower
# Sample predictions: ['get', 'get', 'h', 'get', 'get']
# Sample expected: ['m', 'k', 'h', 'f', 'm']
# Sample predictions: ['b', 'e', 't', 'h', 'x']
# Sample expected: ['b', 'e', 't', 'h', 'x']
# Baseline Accuracy: 0.04  (6.2s)
# ICL Accuracy: 1.00  (7.5s)
#
# ==================================================
# Running task 10/21: algorithmic_char_to_int
# Sample predictions: ['get', 'get', 'd', 'c', 'get']
# Sample expected: ['7', '6', '4', '3', '7']
# Sample predictions: ['1', '3', '10', '4', '9']
# Sample expected: ['1', '4', '7', '9', '1']
# Baseline Accuracy: 0.00  (6.2s)
# ICL Accuracy: 0.12  (7.4s)
#
# ==================================================
# Running task 11/21: algorithmic_int_to_char
# Sample predictions: ['get', 'get', 'get', 'get', 'get']
# Sample expected: ['g', 'f', 'd', 'c', 'g']
# Sample predictions: ['a', 'c', 'j', 'g', 'i']
# Sample expected: ['a', 'd', 'g', 'i', 'a']
# Baseline Accuracy: 0.00  (6.1s)
# ICL Accuracy: 0.18  (7.6s)
#
# ==================================================
# Running task 12/21: linguistic_present_simple_gerund
# Sample predictions: ['get', 'get', 'get', 'get', 'get']
# Sample expected: [' quoting', ' offering', ' handing', ' eating', ' reaching']
# Sample predictions: [' back', ' healing', ' growing', ' switching', ' examining']
# Sample expected: [' backing', ' healing', ' growing', ' switching', ' examining']
# Baseline Accuracy: 0.00  (6.1s)
# ICL Accuracy: 0.88  (7.6s)
#
# ==================================================
# Running task 13/21: linguistic_present_simple_past_simple
# Sample predictions: ['get', 'lock', '', 'draw', 'get']
# Sample expected: [' peeled', ' locked', ' forgot', ' drew', ' picked']
# Sample predictions: [' part', ' caught', ' flooded', ' stretched', ' cost']
# Sample expected: [' parted', ' caught', ' flooded', ' stretched', ' cost']
# Baseline Accuracy: 0.00  (6.1s)
# ICL Accuracy: 0.88  (7.6s)
#
# ==================================================
# Running task 14/21: linguistic_present_simple_past_perfect
# Sample predictions: ['get', '', 'get', 'draw', ',']
# Sample expected: [' made', ' known', ' flown', ' drawn', ' meant']
# Sample predictions: [' let', ' grew', ' keep', ' fought', ' drove']
# Sample expected: [' let', ' grown', ' kept', ' fought', ' driven']
# Baseline Accuracy: 0.01  (6.1s)
# ICL Accuracy: 0.58  (7.5s)
#
# ==================================================
# Running task 15/21: linguistic_singular_plural
# Sample predictions: ['get', 'mouse', '', 'get', '']
# Sample expected: [' people', ' mice', ' hypotheses', ' fish', ' phenomena']
# Sample predictions: [' analysis', ' index', ' hypotheses', ' that', ' echo']
# Sample expected: [' analyses', ' indices', ' hypotheses', ' those', ' echoes']
# Baseline Accuracy: 0.00  (6.2s)
# ICL Accuracy: 0.68  (7.7s)
#
# ==================================================
# Running task 16/21: linguistic_plural_singular
# Sample predictions: ['get', 'left', '', '', 'get']
# Sample expected: [' measles', ' leaf', ' foot', ' deer', ' medium']
# Sample predictions: [' vertex', ' swine', ' emph', ' vortex', ' series']
# Sample expected: [' vertex', ' swine', ' emphasis', ' vortex', ' series']
# Baseline Accuracy: 0.00  (6.4s)
# ICL Accuracy: 0.76  (8.0s)
#
# ==================================================
# Running task 17/21: linguistic_antonyms
# Sample predictions: ['odd', '', 'get', 'error', 'get']
# Sample expected: [' even', ' quiet', ' stop', ' succeed', ' refuse']
# Sample predictions: [' even', ' fail', ' innocent', ' safe', ' noisy']
# Sample expected: [' even', ' succeed', ' innocent', ' dangerous', ' loud']
# Baseline Accuracy: 0.13  (6.1s)
# ICL Accuracy: 0.56  (7.5s)
#
# ==================================================
# Running task 18/21: knowledge_country_capital
# Sample predictions: ['', '', '', '', 'Q']
# Sample expected: ['Venice', 'Berlin', 'Paris', 'Berlin', 'Beijing']
# Sample predictions: ['The', 'M', 'D', 'An', 'London']
# Sample expected: ['Athens', 'Mumbai', 'Dublin', 'Ankara', 'London']
# Baseline Accuracy: 0.00  (7.3s)
# ICL Accuracy: 0.60  (12.3s)
#
# ==================================================
# Running task 19/21: knowledge_person_language
# Sample predictions: ['', '', '', '', '']
# Sample expected: ['Ukrainian', 'English', 'Dutch', 'French', 'Italian']
# Sample predictions: ['Russian', 'French', 'Dutch', 'Spanish', 'Spanish']
# Sample expected: ['Russian', 'French', 'Dutch', 'Spanish', 'Spanish']
# Baseline Accuracy: 0.01  (8.1s)
# ICL Accuracy: 0.76  (13.0s)
#
# ==================================================
# Running task 20/21: knowledge_location_continent
# Sample predictions: ['', '', '', '', '']
# Sample expected: ['Asia', 'Antarctica', 'Antarctica', 'Africa', 'Antarctica']
# Sample predictions: ['Asia', 'An', 'Europe', 'An', 'An']
# Sample expected: ['Asia', 'Africa', 'Antarctica', 'Antarctica', 'Antarctica']
# Baseline Accuracy: 0.00  (7.5s)
# ICL Accuracy: 0.62  (12.8s)
#
# ==================================================
# Running task 21/21: knowledge_location_religion
# Sample predictions: ['', 'get', '', '', '']
# Sample expected: ['Muslim', 'Jewish', 'Jewish', 'Christian', 'Jewish']
# Sample predictions: ['Christian', 'Muslim', 'Muslim', 'Muslim', 'Muslim']
# Sample expected: ['Muslim', 'Christian', 'Christian', 'Muslim', 'Muslim']
# Baseline Accuracy: 0.00  (8.1s)
# ICL Accuracy: 0.54  (13.2s)
#
#   Loading transformer from HuggingFace: EleutherAI/pythia-410m
# Loading weights:   0%|          | 0/292 [00:00<?, ?it/s]
# Evaluating transformer_~370M_pile on ICL...
#
# ==================================================
# Running task 1/21: algorithmic_next_letter
# Sample predictions: ['m', 's', 'p', 'get', 'm']
# Sample expected: ['n', 'l', 'i', 'g', 'n']
# Sample predictions: ['o', 's', 'p', 'o', 'j']
# Sample expected: ['z', 'v', 'o', 'y', 'w']
# Baseline Accuracy: 0.00  (2.1s)
# ICL Accuracy: 0.38  (1.1s)
#
# ==================================================
# Running task 2/21: algorithmic_prev_letter
# Sample predictions: ['s', 's', 'i', 'get', 's']
# Sample expected: ['m', 'k', 'h', 'f', 'm']
# Sample predictions: ['n', 't', 'l', 'n', 'i']
# Sample expected: ['y', 'u', 'n', 'x', 'v']
# Baseline Accuracy: 0.00  (2.0s)
# ICL Accuracy: 0.02  (1.1s)
#
# ==================================================
# Running task 3/21: algorithmic_list_first
# Sample predictions: ['i', 'p', 'w', 'r', 'x']
# Sample expected: ['i', 'p', 'w', 'r', 'y']
# Sample predictions: ['q', 'n', 'z', 'l', 'y']
# Sample expected: ['q', 'n', 'z', 'l', 'y']
# Baseline Accuracy: 0.36  (2.1s)
# ICL Accuracy: 1.00  (1.1s)
#
# ==================================================
# Running task 4/21: algorithmic_list_last
# Sample predictions: ['i', 'p', 'w', 'r', 'x']
# Sample expected: ['x', 'o', 'a', 'v', 'z']
# Sample predictions: ['y', 'p', 's', 'u', 'f']
# Sample expected: ['y', 'p', 's', 'u', 'f']
# Baseline Accuracy: 0.20  (2.1s)
# ICL Accuracy: 0.98  (1.1s)
#
# ==================================================
# Running task 5/21: algorithmic_list_min
# Sample predictions: ['', '', '0', '0', '']
# Sample expected: ['3', '5', '0', '6', '9']
# Sample predictions: ['1', '5', '1', '4', '9']
# Sample expected: ['3', '5', '3', '4', '2']
# Baseline Accuracy: 0.17  (2.1s)
# ICL Accuracy: 0.58  (1.1s)
#
# ==================================================
# Running task 6/21: algorithmic_list_max
# Sample predictions: ['', '', '0', '0', '']
# Sample expected: ['9', '6', '8', '8', '9']
# Sample predictions: ['9', '5', '7', '4', '9']
# Sample expected: ['9', '7', '9', '7', '9']
# Baseline Accuracy: 0.00  (2.1s)
# ICL Accuracy: 0.46  (1.1s)
#
# ==================================================
# Running task 7/21: algorithmic_list_length
# Sample predictions: ['i', 'p', 't', 's', 'x']
# Sample expected: ['2', '2', '3', '1', '3']
# Sample predictions: ['3', '3', '1', '1', '1']
# Sample expected: ['1', '3', '1', '1', '2']
# Baseline Accuracy: 0.00  (2.1s)
# ICL Accuracy: 0.46  (1.1s)
#
# ==================================================
# Running task 8/21: algorithmic_to_upper
# Sample predictions: ['m', 's', 'p', 'get', 'm']
# Sample expected: ['M', 'K', 'H', 'F', 'M']
# Sample predictions: ['B', 'E', 'T', 'H', 'X']
# Sample expected: ['B', 'E', 'T', 'H', 'X']
# Baseline Accuracy: 0.00  (2.1s)
# ICL Accuracy: 1.00  (1.1s)
#
# ==================================================
# Running task 9/21: algorithmic_to_lower
# Sample predictions: ['get', 'get', 'get', 'get', 'get']
# Sample expected: ['m', 'k', 'h', 'f', 'm']
# Sample predictions: ['b', 'e', 't', 'h', 'x']
# Sample expected: ['b', 'e', 't', 'h', 'x']
# Baseline Accuracy: 0.00  (2.0s)
# ICL Accuracy: 1.00  (1.1s)
#
# ==================================================
# Running task 10/21: algorithmic_char_to_int
# Sample predictions: ['get', 'get', 'p', 'p', 'get']
# Sample expected: ['7', '6', '4', '3', '7']
# Sample predictions: ['1', '3', '2', '4', '9']
# Sample expected: ['1', '4', '7', '9', '1']
# Baseline Accuracy: 0.00  (2.0s)
# ICL Accuracy: 0.12  (1.1s)
#
# ==================================================
# Running task 11/21: algorithmic_int_to_char
# Sample predictions: ['get', 'get', 'get', 'get', 'get']
# Sample expected: ['g', 'f', 'd', 'c', 'g']
# Sample predictions: ['a', 'c', 'j', 'a', 'b']
# Sample expected: ['a', 'd', 'g', 'i', 'a']
# Baseline Accuracy: 0.00  (2.1s)
# ICL Accuracy: 0.18  (1.1s)
#
# ==================================================
# Running task 12/21: linguistic_present_simple_gerund
# Sample predictions: ['', '', 'get', 'get', 'end']
# Sample expected: [' quoting', ' offering', ' handing', ' eating', ' reaching']
# Sample predictions: [' back', ' healing', ' growing', ' switching', ' examining']
# Sample expected: [' backing', ' healing', ' growing', ' switching', ' examining']
# Baseline Accuracy: 0.00  (2.1s)
# ICL Accuracy: 0.74  (1.1s)
#
# ==================================================
# Running task 13/21: linguistic_present_simple_past_simple
# Sample predictions: ['', 'lock', '', 'get', 'id']
# Sample expected: [' peeled', ' locked', ' forgot', ' drew', ' picked']
# ...
# Sample predictions: ['m', 'k', 'h', 'f', 'm']
# Sample expected: ['n', 'l', 'i', 'g', 'n']
# Sample predictions: ['z', 'v', 'o', 'y', 'y']
# Sample expected: ['z', 'v', 'o', 'y', 'w']
# Baseline Accuracy: 0.00  (8.5s)
# ICL Accuracy: 0.84  (10.2s)
#
# ==================================================
# Running task 2/21: algorithmic_prev_letter
# Sample predictions: ['n', 'l', 'i', 'g', 'n']
# Sample expected: ['m', 'k', 'h', 'f', 'm']
# Sample predictions: ['o', 'w', 'n', 'u', 'x']
# Sample expected: ['y', 'u', 'n', 'x', 'v']
# Baseline Accuracy: 0.00  (8.5s)
# ICL Accuracy: 0.14  (10.2s)
#
# ==================================================
# Running task 3/21: algorithmic_list_first
# Sample predictions: ['y', 'p', 'w', 'r', 'y']
# Sample expected: ['i', 'p', 'w', 'r', 'y']
# Sample predictions: ['q', 'n', 'z', 'l', 'y']
# Sample expected: ['q', 'n', 'z', 'l', 'y']
# Baseline Accuracy: 0.45  (10.8s)
# ICL Accuracy: 1.00  (17.2s)
#
# ==================================================
# Running task 4/21: algorithmic_list_last
# Sample predictions: ['y', 'p', 'w', 'r', 'y']
# Sample expected: ['x', 'o', 'a', 'v', 'z']
# Sample predictions: ['y', 'p', 's', 'u', 'f']
# Sample expected: ['y', 'p', 's', 'u', 'f']
# Baseline Accuracy: 0.42  (10.8s)
# ICL Accuracy: 0.98  (17.2s)
#
# ==================================================
# Running task 5/21: algorithmic_list_min
# Sample predictions: ['0', '6', '8', '7', '9']
# Sample expected: ['3', '5', '0', '6', '9']
# Sample predictions: ['9', '5', '3', '4', '2']
# Sample expected: ['3', '5', '3', '4', '2']
# Baseline Accuracy: 0.37  (10.8s)
# ICL Accuracy: 0.58  (17.1s)
#
# ==================================================
# Running task 6/21: algorithmic_list_max
# Sample predictions: ['0', '6', '8', '7', '9']
# Sample expected: ['9', '6', '8', '8', '9']
# Sample predictions: ['9', '7', '7', '7', '9']
# Sample expected: ['9', '7', '9', '7', '9']
# Baseline Accuracy: 0.19  (10.8s)
# ICL Accuracy: 0.72  (17.2s)
#
# ==================================================
# Running task 7/21: algorithmic_list_length
# Sample predictions: ['c', 'p', 't', 'u', 'y']
# Sample expected: ['2', '2', '3', '1', '3']
# Sample predictions: ['3', '1', '1', '1', '2']
# Sample expected: ['1', '3', '1', '1', '2']
# Baseline Accuracy: 0.00  (9.9s)
# ICL Accuracy: 0.50  (13.7s)
#
# ==================================================
# Running task 8/21: algorithmic_to_upper
# Sample predictions: ['m', 'k', 'h', 'f', 'm']
# Sample expected: ['M', 'K', 'H', 'F', 'M']
# Sample predictions: ['B', 'E', 'T', 'H', 'X']
# Sample expected: ['B', 'E', 'T', 'H', 'X']
# Baseline Accuracy: 0.00  (8.5s)
# ICL Accuracy: 1.00  (10.2s)
#
# ==================================================
# Running task 9/21: algorithmic_to_lower
# Sample predictions: ['get', 'get', 'get', 'get', 'get']
# Sample expected: ['m', 'k', 'h', 'f', 'm']
# Sample predictions: ['b', 'e', 't', 'h', 'x']
# Sample expected: ['b', 'e', 't', 'h', 'x']
# Baseline Accuracy: 0.00  (8.5s)
# ICL Accuracy: 1.00  (10.2s)
#
# ==================================================
# Running task 10/21: algorithmic_char_to_int
# Sample predictions: ['g', 'f', 'dev', 'dev', 'g']
# Sample expected: ['7', '6', '4', '3', '7']
# Sample predictions: ['1', '4', '6', '7', '9']
# Sample expected: ['1', '4', '7', '9', '1']
# Baseline Accuracy: 0.00  (8.5s)
# ICL Accuracy: 0.32  (10.3s)
#
# ==================================================
# Running task 11/21: algorithmic_int_to_char
# Sample predictions: ['get', 'get', 'get', 'get', 'get']
# Sample expected: ['g', 'f', 'd', 'c', 'g']
# Sample predictions: ['a', 'd', 'j', 'g', 'i']
# Sample expected: ['a', 'd', 'g', 'i', 'a']
# Baseline Accuracy: 0.00  (8.4s)
# ICL Accuracy: 0.40  (10.2s)
#
# ==================================================
# Running task 12/21: linguistic_present_simple_gerund
# Sample predictions: ['get', 'get', 'get', 'get', 'get']
# Sample expected: [' quoting', ' offering', ' handing', ' eating', ' reaching']
# Sample predictions: [' back', ' healing', ' growing', ' switching', ' examining']
# Sample expected: [' backing', ' healing', ' growing', ' switching', ' examining']
# Baseline Accuracy: 0.00  (8.5s)
# ICL Accuracy: 0.98  (10.5s)
#
# ==================================================
# Running task 13/21: linguistic_present_simple_past_simple
# Sample predictions: ['get', 'lock', '', 'Get', 'get']
# Sample expected: [' peeled', ' locked', ' forgot', ' drew', ' picked']
# Sample predictions: [' parts', ' caught', ' flooded', ' stretched', ' cost']
# Sample expected: [' parted', ' caught', ' flooded', ' stretched', ' cost']
# Baseline Accuracy: 0.00  (8.6s)
# ICL Accuracy: 0.92  (10.3s)
#
# ==================================================
# Running task 14/21: linguistic_present_simple_past_perfect
# Sample predictions: ['get', '', 'get', 'Get', 'get']
# Sample expected: [' made', ' known', ' flown', ' drawn', ' meant']
# Sample predictions: [' let', ' grew', ' kept', ' fought', ' drove']
# Sample expected: [' let', ' grown', ' kept', ' fought', ' driven']
# Baseline Accuracy: 0.00  (8.5s)
# ICL Accuracy: 0.74  (10.3s)
#
# ==================================================
# Running task 15/21: linguistic_singular_plural
# Sample predictions: ['name', 'Get', '', 'dev', '']
# Sample expected: [' people', ' mice', ' hypotheses', ' fish', ' phenomena']
# Sample predictions: [' analyses', ' index', ' hypotheses', ' that', ' echoes']
# Sample expected: [' analyses', ' indices', ' hypotheses', ' those', ' echoes']
# Baseline Accuracy: 0.00  (8.6s)
# ICL Accuracy: 0.82  (10.5s)
#
# ==================================================
# Running task 16/21: linguistic_plural_singular
# Sample predictions: ['', 'right', 'feet', '', 'get']
# Sample expected: [' measles', ' leaf', ' foot', ' deer', ' medium']
# Sample predictions: [' vertex', ' swine', ' emphasis', ' vortex', ' series']
# Sample expected: [' vertex', ' swine', ' emphasis', ' vortex', ' series']
# Baseline Accuracy: 0.00  (8.6s)
# ICL Accuracy: 0.96  (10.9s)
#
# ==================================================
# Running task 17/21: linguistic_antonyms
# Sample predictions: ['', '', 'get', 'name', 'get']
# Sample expected: [' even', ' quiet', ' stop', ' succeed', ' refuse']
# Sample predictions: [' even', ' fail', ' innocent', ' unsafe', ' loud']
# Sample expected: [' even', ' succeed', ' innocent', ' dangerous', ' loud']
# Baseline Accuracy: 0.06  (8.5s)
# ICL Accuracy: 0.74  (10.2s)
#
# ==================================================
# Running task 18/21: knowledge_country_capital
# Sample predictions: ['Ven', 'N', 'King', '', '']
# Sample expected: ['Venice', 'Berlin', 'Paris', 'Berlin', 'Beijing']
# Sample predictions: ['A', 'M', 'D', 'I', 'London']
# Sample expected: ['Athens', 'Mumbai', 'Dublin', 'Ankara', 'London']
# Baseline Accuracy: 0.08  (9.9s)
# ICL Accuracy: 0.84  (16.5s)
#
# ==================================================
# Running task 19/21: knowledge_person_language
# Sample predictions: ['>', '', '', ' http', '']
# Sample expected: ['Ukrainian', 'English', 'Dutch', 'French', 'Italian']
# Sample predictions: ['Russian', 'French', 'Dutch', 'Spanish', 'Spanish']
# Sample expected: ['Russian', 'French', 'Dutch', 'Spanish', 'Spanish']
# Baseline Accuracy: 0.00  (11.1s)
# ICL Accuracy: 0.84  (17.7s)
#
# ==================================================
# Running task 20/21: knowledge_location_continent
# Sample predictions: ['', '', '', '', '']
# Sample expected: ['Asia', 'Antarctica', 'Antarctica', 'Africa', 'Antarctica']
# Sample predictions: ['Asia', 'Af', 'An', 'An', 'An']
# Sample expected: ['Asia', 'Africa', 'Antarctica', 'Antarctica', 'Antarctica']
# Baseline Accuracy: 0.00  (10.3s)
# ICL Accuracy: 0.82  (17.2s)
#
# ==================================================
# Running task 21/21: knowledge_location_religion
# Sample predictions: ['', 'set', '', '', ' I']
# Sample expected: ['Muslim', 'Jewish', 'Jewish', 'Christian', 'Jewish']
# Sample predictions: ['Muslim', 'Jewish', 'Cath', 'Muslim', 'Muslim']
# Sample expected: ['Muslim', 'Christian', 'Christian', 'Muslim', 'Muslim']
# Baseline Accuracy: 0.01  (11.1s)
# ICL Accuracy: 0.84  (17.9s)
#
#   Loading transformer from HuggingFace: EleutherAI/pythia-2.8b
# Loading weights:   0%|          | 0/388 [00:00<?, ?it/s]
# Evaluating transformer_~2.8B_pile on ICL...
#
# ==================================================
# Running task 1/21: algorithmic_next_letter
# Sample predictions: ['m', 'k', 'h', 'get', 'm']
# Sample expected: ['n', 'l', 'i', 'g', 'n']
# Sample predictions: ['z', 'v', 'q', 'y', 'j']
# Sample expected: ['z', 'v', 'o', 'y', 'w']
# Baseline Accuracy: 0.08  (4.9s)
# ICL Accuracy: 0.78  (2.8s)
#
# ==================================================
# Running task 2/21: algorithmic_prev_letter
# Sample predictions: ['n', 'l', 'i', 'get', 'n']
# Sample expected: ['m', 'k', 'h', 'f', 'm']
# Sample predictions: ['v', 'w', 'r', 'x', 'x']
# Sample expected: ['y', 'u', 'n', 'x', 'v']
# Baseline Accuracy: 0.00  (4.9s)
# ICL Accuracy: 0.28  (2.8s)
#
# ==================================================
# Running task 3/21: algorithmic_list_first
# Sample predictions: ['i', 'p', 'a', 'r', 'y']
# Sample expected: ['i', 'p', 'w', 'r', 'y']
# Sample predictions: ['q', 'n', 'z', 'l', 'y']
# Sample expected: ['q', 'n', 'z', 'l', 'y']
# Baseline Accuracy: 0.49  (5.2s)
# ICL Accuracy: 1.00  (3.6s)
#
# ==================================================
# Running task 4/21: algorithmic_list_last
# Sample predictions: ['i', 'p', 'a', 'r', 'y']
# Sample expected: ['x', 'o', 'a', 'v', 'z']
# Sample predictions: ['y', 'p', 's', 'u', 'f']
# Sample expected: ['y', 'p', 's', 'u', 'f']
# Baseline Accuracy: 0.29  (5.2s)
# ICL Accuracy: 1.00  (3.6s)
#
# ==================================================
# Running task 5/21: algorithmic_list_min
# Sample predictions: ['3', '6', '8', '9', '9']
# Sample expected: ['3', '5', '0', '6', '9']
# Sample predictions: ['9', '6', '3', '4', '9']
# Sample expected: ['3', '5', '3', '4', '2']
# Baseline Accuracy: 0.31  (5.2s)
# ICL Accuracy: 0.48  (3.5s)
#
# ==================================================
# Running task 6/21: algorithmic_list_max
# Sample predictions: ['3', '6', '8', '9', '9']
# Sample expected: ['9', '6', '8', '8', '9']
# Sample predictions: ['9', '5', '7', '7', '9']
# Sample expected: ['9', '7', '9', '7', '9']
# Baseline Accuracy: 0.30  (5.2s)
# ICL Accuracy: 0.62  (3.5s)
#
# ==================================================
# Running task 7/21: algorithmic_list_length
# Sample predictions: ['i', 'p', 'w', 'dev', 'z']
# Sample expected: ['2', '2', '3', '1', '3']
# Sample predictions: ['2', '2', '1', '1', '1']
# Sample expected: ['1', '3', '1', '1', '2']
# Baseline Accuracy: 0.00  (5.1s)
# ICL Accuracy: 0.52  (3.1s)
#
# ==================================================
# Running task 8/21: algorithmic_to_upper
# Sample predictions: ['m', 'k', 'h', 'get', 'm']
# Sample expected: ['M', 'K', 'H', 'F', 'M']
# Sample predictions: ['B', 'E', 'T', 'H', 'X']
# Sample expected: ['B', 'E', 'T', 'H', 'X']
# Baseline Accuracy: 0.00  (4.9s)
# ICL Accuracy: 1.00  (2.8s)
#
# ==================================================
# Running task 9/21: algorithmic_to_lower
# Sample predictions: ['get', 'i', 'get', 'get', 'get']
# Sample expected: ['m', 'k', 'h', 'f', 'm']
# Sample predictions: ['b', 'e', 't', 'h', 'x']
# Sample expected: ['b', 'e', 't', 'h', 'x']
# Baseline Accuracy: 0.00  (4.9s)
# ICL Accuracy: 1.00  (2.8s)
#
# ==================================================
# Running task 10/21: algorithmic_char_to_int
# Sample predictions: ['get', 'get', 'dev', 'dev', 'get']
# Sample expected: ['7', '6', '4', '3', '7']
# Sample predictions: ['1', '3', '7', '4', '9']
# Sample expected: ['1', '4', '7', '9', '1']
# Baseline Accuracy: 0.00  (4.9s)
# ICL Accuracy: 0.26  (2.8s)
#
# ==================================================
# Running task 11/21: algorithmic_int_to_char
# Sample predictions: ['get', 'get', 'get', 'get', 'get']
# Sample expected: ['g', 'f', 'd', 'c', 'g']
# Sample predictions: ['a', 'd', 'g', 'g', 'a']
# Sample expected: ['a', 'd', 'g', 'i', 'a']
# Baseline Accuracy: 0.00  (4.9s)
# ICL Accuracy: 0.42  (2.8s)
#
# ==================================================
# Running task 12/21: linguistic_present_simple_gerund
# Sample predictions: ['get', 'get', 'get', '', 'get']
# Sample expected: [' quoting', ' offering', ' handing', ' eating', ' reaching']
# Sample predictions: [' back', ' healing', ' growing', ' switching', ' examining']
# Sample expected: [' backing', ' healing', ' growing', ' switching', ' examining']
# Baseline Accuracy: 0.00  (4.9s)
# ICL Accuracy: 0.94  (2.8s)
#
# ==================================================
# Running task 13/21: linguistic_present_simple_past_simple
# Sample predictions: ['get', 'lock', '', 'draw', 'get']
# Sample expected: [' peeled', ' locked', ' forgot', ' drew', ' picked']
# Sample predictions: [' part', ' caught', ' flooded', ' stretched', ' cost']
# Sample expected: [' parted', ' caught', ' flooded', ' stretched', ' cost']
# Baseline Accuracy: 0.00  (4.9s)
# ICL Accuracy: 0.90  (2.8s)
#
# ==================================================
# Running task 14/21: linguistic_present_simple_past_perfect
# Sample predictions: ['get', '', 'i', 'draw', 'get']
# Sample expected: [' made', ' known', ' flown', ' drawn', ' meant']
# Sample predictions: [' let', ' grew', ' kept', ' fought', ' drove']
# Sample expected: [' let', ' grown', ' kept', ' fought', ' driven']
# Baseline Accuracy: 0.00  (4.9s)
# ICL Accuracy: 0.74  (2.8s)
#
# ==================================================
# Running task 15/21: linguistic_singular_plural
# Sample predictions: ['get', 'x', 'get', 'get', 'get']
# Sample expected: [' people', ' mice', ' hypotheses', ' fish', ' phenomena']
# Sample predictions: [' analyses', ' index', ' hypotheses', ' that', ' echoes']
# Sample expected: [' analyses', ' indices', ' hypotheses', ' those', ' echoes']
# Baseline Accuracy: 0.00  (4.9s)
# ICL Accuracy: 0.78  (2.8s)
#
# ==================================================
# Running task 16/21: linguistic_plural_singular
# Sample predictions: ['i', 'next', '', 'get', 'dev']
# Sample expected: [' measles', ' leaf', ' foot', ' deer', ' medium']
# Sample predictions: [' vertex', ' swine', ' emph', ' vortex', ' series']
# Sample expected: [' vertex', ' swine', ' emphasis', ' vortex', ' series']
# Baseline Accuracy: 0.00  (4.9s)
# ICL Accuracy: 0.90  (2.8s)
#
# ==================================================
# Running task 17/21: linguistic_antonyms
# Sample predictions: ['next', '', 'i', 'status', 'get']
# Sample expected: [' even', ' quiet', ' stop', ' succeed', ' refuse']
# Sample predictions: [' even', ' succeed', ' innocent', ' unsafe', ' noisy']
# Sample expected: [' even', ' succeed', ' innocent', ' dangerous', ' loud']
# Baseline Accuracy: 0.03  (4.9s)
# ICL Accuracy: 0.72  (2.8s)
#
# ==================================================
# Running task 18/21: knowledge_country_capital
# Sample predictions: ['', 'N', 'France', '', 'Q']
# Sample expected: ['Venice', 'Berlin', 'Paris', 'Berlin', 'Beijing']
# Sample predictions: ['A', 'B', 'D', 'An', 'New']
# Sample expected: ['Athens', 'Mumbai', 'Dublin', 'Ankara', 'London']
# Baseline Accuracy: 0.07  (5.1s)
# ICL Accuracy: 0.64  (3.5s)
#
# ==================================================
# Running task 19/21: knowledge_person_language
# Sample predictions: ['', '', '', 'get', '']
# Sample expected: ['Ukrainian', 'English', 'Dutch', 'French', 'Italian']
# Sample predictions: ['Russian', 'French', 'Dutch', 'Spanish', 'Spanish']
# Sample expected: ['Russian', 'French', 'Dutch', 'Spanish', 'Spanish']
# Baseline Accuracy: 0.01  (5.2s)
# ICL Accuracy: 0.82  (3.5s)
#
# ==================================================
# Running task 20/21: knowledge_location_continent
# Sample predictions: ['>', '', 'D', 'Ch', 'South']
# Sample expected: ['Asia', 'Antarctica', 'Antarctica', 'Africa', 'Antarctica']
# Sample predictions: ['Asia', 'An', 'An', 'An', 'An']
# Sample expected: ['Asia', 'Africa', 'Antarctica', 'Antarctica', 'Antarctica']
# Baseline Accuracy: 0.02  (5.1s)
# ICL Accuracy: 0.80  (3.5s)
#
# ==================================================
# Running task 21/21: knowledge_location_religion
# Sample predictions: ['', '', 'The', '', '']
# Sample expected: ['Muslim', 'Jewish', 'Jewish', 'Christian', 'Jewish']
# Sample predictions: ['Muslim', 'Muslim', 'Christian', 'Muslim', 'Muslim']
# Sample expected: ['Muslim', 'Christian', 'Christian', 'Muslim', 'Muslim']
# Baseline Accuracy: 0.02  (5.2s)
# ICL Accuracy: 0.80  (3.5s)
