# %% [markdown]
# ### Setup

# %%
# %pip install schedule bitsandbytes -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 44.6 MB/s eta 0:00:00:00:0100:01

# %% [markdown]
# ### Clone GitHub Repository and Add to System Path

# %%
# --- Configuration for your GitHub Repository ---
GITHUB_REPO_URL = "https://github.com/JackMclaughlin424/csci739-project-mamba.git" # Replace with your GitHub repository URL
REPO_NAME = "csci739-project-mamba"
COMMIT_HASH = None # Set this to a specific commit hash (e.g., "your_commit_hash") to check out that commit. If None, the latest commit on the specified branch will be used.
BRANCH_NAME = "experiments" # Set this to the name of the branch you want to clone (e.g., "dev", "main"). If None, the default branch will be cloned.
SUBDIRECTORY = "" # If your project code is in a subdirectory (e.g., 'Colab resources/style-prompt-generator'), specify it here. Otherwise, set to None or an empty string.

# %% [markdown]
# **Clear GitHub Repository**

# %%
import shutil
import os

# Ensure REPO_NAME is defined (it should be from previous cells)
if 'REPO_NAME' in globals() and REPO_NAME:
    repo_path = f'/content/{REPO_NAME}'
    if os.path.exists(repo_path):
        print(f'Removing {repo_path}...')
        shutil.rmtree(repo_path)
        print(f'{repo_path} removed successfully.')
    else:
        print(f'Repository directory {repo_path} does not exist.')
else:
    print('REPO_NAME variable not found or is empty. Please ensure the repository name is set.')
# Out:
# Repository directory /content/csci739-project-mamba does not exist.

# %% [markdown]
# **Clone repo**

# %%
import os
import sys


# Construct the git clone command
clone_command = f"git clone "
if BRANCH_NAME:
    clone_command += f"--branch {BRANCH_NAME} "
clone_command += f"{GITHUB_REPO_URL} /content/{REPO_NAME}"

# Clone the repository
get_ipython().system(clone_command)

# Navigate into the cloned directory
# %cd /content/{REPO_NAME}

# Checkout a specific commit if provided
if COMMIT_HASH:
    print(f"Checking out commit: {COMMIT_HASH}")
    get_ipython().system(f"git checkout {COMMIT_HASH}")
else:
    if not BRANCH_NAME:
        print("Using the latest commit on the default branch.")
    else:
        print(f"Using the latest commit on branch: {BRANCH_NAME}")

# Navigate back to the content directory (or stay in the repo root if that's where the code is)
# %cd /content

# Add the repository (or its subdirectory) to sys.path
repo_path = f"/content/{REPO_NAME}"
if SUBDIRECTORY:
    repo_path = os.path.join(repo_path, SUBDIRECTORY)

if repo_path not in sys.path:
    sys.path.insert(0, repo_path)
    print(f"Added {repo_path} to sys.path")
else:
    print(f"{repo_path} is already in sys.path")

print("Current sys.path:")
for p in sys.path:
    print(p)
# Out:
# Cloning into '/content/csci739-project-mamba'...
# remote: Enumerating objects: 578, done.
# remote: Counting objects: 100% (234/234), done.
# remote: Compressing objects: 100% (175/175), done.
# remote: Total 578 (delta 115), reused 139 (delta 59), pack-reused 344 (from 1)
# Receiving objects: 100% (578/578), 4.85 MiB | 11.13 MiB/s, done.
# Resolving deltas: 100% (246/246), done.
# /content/csci739-project-mamba
# Using the latest commit on branch: experiments
# /content
# Added /content/csci739-project-mamba to sys.path
# Current sys.path:
# /content/csci739-project-mamba
# /content
# /env/python
# /usr/lib/python312.zip
# /usr/lib/python3.12
# /usr/lib/python3.12/lib-dynload
#
# /usr/local/lib/python3.12/dist-packages
# /usr/lib/python3/dist-packages
# /usr/local/lib/python3.12/dist-packages/IPython/extensions
# /root/.ipython

# %% [markdown]
# ### Set W&B API Key from Colab Secrets
#
# This cell will retrieve your Weights & Biases API key from Colab's 'Secrets' and set it as an environment variable, making it accessible to `os.environ.get()` within your `train.py` script.

# %% [markdown]
# set hf token

# %%
# # HF_TOKEN = userdata.get('HF_TOKEN')


# if HF_TOKEN:
#     os.environ['HF_TOKEN'] = HF_TOKEN
#     print("HF_TOKEN loaded from Colab secrets and set as environment variable.")
# else:
#     print("HF_TOKEN not found in Colab secrets. Please ensure it's set there.")

# import huggingface_hub
# huggingface_hub.login(token=os.environ['HF_TOKEN'], add_to_git_credential=False)

# %% [markdown]
# ### Mount drive for accessing data in Colab

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# Add path so imports work
import sys
sys.path.insert(0, "/content/drive/MyDrive/csci739_GenAI_topics/project_resources")
# Out:
# Mounted at /content/drive

# %%
blurp # force fail
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3832/3689156905.py in <cell line: 0>()
# ----> 1 blurp # force fail
#
# NameError: name 'blurp' is not defined

# %% [markdown]
# ## Run in context learning expeirments
#
# ### SPecific model

# %%
import sys
sys.argv = [
    "icl_tasks.py",
    "--model_path",    "/content/drive/MyDrive/csci739_GenAI_topics/project_resources/mamba_simplestories_5m.pt",
    "--model_variant", "5m",
    "--tokenizer_name", "SimpleStories/SimpleStories-5M",
]

# %%
from icl_tasks import main
main()

# %% [markdown]
# ### All models

# %%
import sys
sys.path.insert(0, "csci739-project-mamba/experiments")

from experiment_pretrained_icl import run_experiments
run_experiments()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# Running on device: cuda
#
# ============================================================
# Experiment: 5M_SimpleStories
#
#   Loading ssm from checkpoint: /content/drive/MyDrive/csci739_GenAI_topics/project_resources/mamba_simplestories_5m_final.pt
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:103: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# config.json:   0%|          | 0.00/667 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/591 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/51.0 [00:00<?, ?B/s]
# Evaluating ssm_5M_SimpleStories on ICL...
# WARNING: mapping present_simple_past_perfect has only 60 examples after filtering (110 before)
# WARNING: mapping singular_plural has only 14 examples after filtering (173 before)
# WARNING: mapping plural_singular has only 23 examples after filtering (172 before)
#
# ==================================================
# Running task 1/21: algorithmic_next_letter
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['n', 'l', 'i', 'g', 'n']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['z', 'v', 'o', 'y', 'w']
# Baseline Accuracy: 0.00  (3.1s)
# ICL Accuracy: 0.00  (1.3s)
#
# ==================================================
# Running task 2/21: algorithmic_prev_letter
# Sample predictions: ['.', '.', ',', '.', '.']
# Sample expected: ['m', 'k', 'h', 'f', 'm']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['y', 'u', 'n', 'x', 'v']
# Baseline Accuracy: 0.00  (2.4s)
# ICL Accuracy: 0.00  (1.2s)
#
# ==================================================
# Running task 3/21: algorithmic_list_first
# Sample predictions: ['!', '.', '.', '.', '.']
# Sample expected: ['i', 'p', 'w', 'r', 'y']
# Sample predictions: ['.', '.', '!', '.', '.']
# Sample expected: ['q', 'n', 'z', 'l', 'y']
# Baseline Accuracy: 0.00  (2.3s)
# ICL Accuracy: 0.00  (1.0s)
#
# ==================================================
# Running task 4/21: algorithmic_list_last
# Sample predictions: ['!', '.', '.', '.', '.']
# Sample expected: ['x', 'o', 'a', 'v', 'z']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['y', 'p', 's', 'u', 'f']
# Baseline Accuracy: 0.00  (2.4s)
# ICL Accuracy: 0.00  (1.0s)
#
# ==================================================
# Running task 5/21: algorithmic_list_min
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['3', '5', '0', '6', '9']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['3', '5', '3', '4', '2']
# Baseline Accuracy: 0.00  (2.3s)
# ICL Accuracy: 0.00  (1.0s)
#
# ==================================================
# Running task 6/21: algorithmic_list_max
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['9', '6', '8', '8', '9']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['9', '7', '9', '7', '9']
# Baseline Accuracy: 0.00  (2.3s)
# ICL Accuracy: 0.00  (1.0s)
#
# ==================================================
# Running task 7/21: algorithmic_list_length
# Sample predictions: [',', '.', '.', '.', '.']
# Sample expected: ['2', '2', '3', '1', '3']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['1', '3', '1', '1', '2']
# Baseline Accuracy: 0.00  (2.4s)
# ICL Accuracy: 0.00  (1.1s)
#
# ==================================================
# Running task 8/21: algorithmic_to_upper
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['M', 'K', 'H', 'F', 'M']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['B', 'E', 'T', 'H', 'X']
# Baseline Accuracy: 0.00  (2.4s)
# ICL Accuracy: 0.00  (1.3s)
#
# ==================================================
# Running task 9/21: algorithmic_to_lower
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['m', 'k', 'h', 'f', 'm']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['b', 'e', 't', 'h', 'x']
# Baseline Accuracy: 0.00  (2.3s)
# ICL Accuracy: 0.00  (1.2s)
#
# ==================================================
# Running task 10/21: algorithmic_char_to_int
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['7', '6', '4', '3', '7']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['1', '4', '7', '9', '1']
# Baseline Accuracy: 0.00  (2.3s)
# ICL Accuracy: 0.00  (1.2s)
#
# ==================================================
# Running task 11/21: algorithmic_int_to_char
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['g', 'f', 'd', 'c', 'g']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['a', 'd', 'g', 'i', 'a']
# Baseline Accuracy: 0.00  (2.4s)
# ICL Accuracy: 0.00  (1.2s)
#
# ==================================================
# Running task 12/21: linguistic_present_simple_gerund
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: [' passing', ' living', ' growing', ' falling', ' picking']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: [' rising', ' sparkling', ' wandering', ' staring', ' rushing']
# Baseline Accuracy: 0.00  (2.4s)
# ICL Accuracy: 0.00  (1.2s)
#
# ==================================================
# Running task 13/21: linguistic_present_simple_past_simple
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: [' raced', ' noticed', ' headed', ' fell', ' read']
# Sample predictions: ['.', '.', '.', '.', ',']
# Sample expected: [' put', ' failed', ' held', ' stepped', ' sensed']
# Baseline Accuracy: 0.00  (2.4s)
# ICL Accuracy: 0.00  (1.2s)
#
# ==================================================
# Running task 14/21: linguistic_present_simple_past_perfect
# WARNING: mapping present_simple_past_perfect has only 60 examples after filtering (110 before)
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: [' heard', ' gone', ' fallen', ' cost', ' worn']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: [' found', ' known', ' sat', ' spun', ' worn']
# Baseline Accuracy: 0.00  (2.3s)
# ICL Accuracy: 0.00  (1.2s)
#
# ==================================================
# Running task 15/21: linguistic_singular_plural
# WARNING: mapping singular_plural has only 14 examples after filtering (173 before)
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: [' heroes', ' feet', ' echoes', ' deer', ' heroes']
# Sample predictions: ['.', ',', '.', '.', '.']
# Sample expected: [' feet', ' means', ' heroes', ' feet', ' châteaus']
# Baseline Accuracy: 0.00  (2.3s)
# ICL Accuracy: 0.00  (1.2s)
#
# ==================================================
# Running task 16/21: linguistic_plural_singular
# WARNING: mapping plural_singular has only 23 examples after filtering (172 before)
# Sample predictions: ['.', ',', '.', '.', '.']
# Sample expected: [' man', ' life', ' half', ' fish', ' man']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: [' mouse', ' person', ' shelf', ' woman', ' deer']
# Baseline Accuracy: 0.00  (2.3s)
# ICL Accuracy: 0.00  (1.2s)
#
# ==================================================
# Running task 17/21: linguistic_antonyms
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: [' follow', ' cold', ' sick', ' bright', ' right']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: [' warm', ' down', ' smooth', ' narrow', ' narrow']
# Baseline Accuracy: 0.00  (2.3s)
# ICL Accuracy: 0.00  (1.2s)
#
# ==================================================
# Running task 18/21: knowledge_country_capital
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['Venice', 'Berlin', 'Paris', 'Berlin', 'Beijing']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['Athens', 'Mumbai', 'Dublin', 'Ankara', 'London']
# Baseline Accuracy: 0.00  (2.3s)
# ICL Accuracy: 0.00  (1.3s)
#
# ==================================================
# Running task 19/21: knowledge_person_language
# Sample predictions: ['.', '.', '.', '.', '!']
# Sample expected: ['Ukrainian', 'English', 'Dutch', 'French', 'Italian']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['Russian', 'French', 'Dutch', 'Spanish', 'Spanish']
# Baseline Accuracy: 0.00  (2.4s)
# ICL Accuracy: 0.00  (1.3s)
#
# ==================================================
# Running task 20/21: knowledge_location_continent
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['Asia', 'Antarctica', 'Antarctica', 'Africa', 'Antarctica']
# Sample predictions: [',', '.', '.', ',', '.']
# Sample expected: ['Asia', 'Africa', 'Antarctica', 'Antarctica', 'Antarctica']
# Baseline Accuracy: 0.00  (2.3s)
# ICL Accuracy: 0.00  (1.2s)
#
# ==================================================
# Running task 21/21: knowledge_location_religion
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['Muslim', 'Jewish', 'Jewish', 'Christian', 'Jewish']
# Sample predictions: ['.', '.', '.', '.', '.']
# Sample expected: ['Muslim', 'Christian', 'Christian', 'Muslim', 'Muslim']
# Baseline Accuracy: 0.00  (2.3s)
# ICL Accuracy: 0.00  (1.3s)
#
#   Loading transformer from HuggingFace: SimpleStories/SimpleStories-5M
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/21.5M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/56 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# Evaluating transformer_5M_SimpleStories on ICL...
# WARNING: mapping present_simple_past_perfect has only 60 examples after filtering (110 before)
# WARNING: mapping singular_plural has only 14 examples after filtering (173 before)
# WARNING: mapping plural_singular has only 23 examples after filtering (172 before)
#
# ==================================================
# Running task 1/21: algorithmic_next_letter
# Sample predictions: ['!', 'together', '!', '!', '!']
# Sample expected: ['n', 'l', 'i', 'g', 'n']
# Sample predictions: ['.', '!', '!', '!', '.']
# Sample expected: ['z', 'v', 'o', 'y', 'w']
# Baseline Accuracy: 0.00  (1.0s)
# ICL Accuracy: 0.00  (0.5s)
#
# ==================================================
# Running task 2/21: algorithmic_prev_letter
# Sample predictions: ['with', ',', '?', '?', 'with']
# Sample expected: ['m', 'k', 'h', 'f', 'm']
# Sample predictions: ['!', '!', '.', '!', '.']
# Sample expected: ['y', 'u', 'n', 'x', 'v']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.4s)
#
# ==================================================
# Running task 3/21: algorithmic_list_first
# Sample predictions: ['!', ',', '##ing', ',', '!']
# Sample expected: ['i', 'p', 'w', 'r', 'y']
# Sample predictions: ['!', '!', '!', '!', ',']
# Sample expected: ['q', 'n', 'z', 'l', 'y']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.5s)
#
# ==================================================
# Running task 4/21: algorithmic_list_last
# Sample predictions: ['!', ',', '##ing', ',', '!']
# Sample expected: ['x', 'o', 'a', 'v', 'z']
# Sample predictions: ['!', '!', '!', '!', ',']
# Sample expected: ['y', 'p', 's', 'u', 'f']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.4s)
#
# ==================================================
# Running task 5/21: algorithmic_list_min
# Sample predictions: ['!', '!', '!', '##s', '##s']
# Sample expected: ['3', '5', '0', '6', '9']
# Sample predictions: ['!', '!', '!', '!', '!']
# Sample expected: ['3', '5', '3', '4', '2']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.4s)
#
# ==================================================
# Running task 6/21: algorithmic_list_max
# Sample predictions: ['!', '!', '!', '##s', '##s']
# Sample expected: ['9', '6', '8', '8', '9']
# Sample predictions: ['!', '!', '!', '!', '!']
# Sample expected: ['9', '7', '9', '7', '9']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.4s)
#
# ==================================================
# Running task 7/21: algorithmic_list_length
# Sample predictions: ['!', ',', '!', '?', '##ing']
# Sample expected: ['2', '2', '3', '1', '3']
# Sample predictions: ['!', '!', '!', '!', '!']
# Sample expected: ['1', '3', '1', '1', '2']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.5s)
#
# ==================================================
# Running task 8/21: algorithmic_to_upper
# Sample predictions: ['!', 'together', '!', '!', '!']
# Sample expected: ['M', 'K', 'H', 'F', 'M']
# Sample predictions: ['!', '!', '!', '!', '!']
# Sample expected: ['B', 'E', 'T', 'H', 'X']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.5s)
#
# ==================================================
# Running task 9/21: algorithmic_to_lower
# Sample predictions: ['!', 'together', '!', '!', '!']
# Sample expected: ['m', 'k', 'h', 'f', 'm']
# Sample predictions: ['!', '!', '!', '!', '!']
# Sample expected: ['b', 'e', 't', 'h', 'x']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.4s)
#
# ==================================================
# Running task 10/21: algorithmic_char_to_int
# Sample predictions: ['?', '!', 'on', 'with', '?']
# Sample expected: ['7', '6', '4', '3', '7']
# Sample predictions: ['!', '!', '!', '!', '!']
# Sample expected: ['1', '4', '7', '9', '1']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.5s)
#
# ==================================================
# Running task 11/21: algorithmic_int_to_char
# Sample predictions: ['!', '##ing', '!', ',', '!']
# Sample expected: ['g', 'f', 'd', 'c', 'g']
# Sample predictions: ['!', '!', '!', '!', '!']
# Sample expected: ['a', 'd', 'g', 'i', 'a']
# Baseline Accuracy: 0.00  (0.8s)
# ICL Accuracy: 0.00  (0.5s)
#
# ==================================================
# Running task 12/21: linguistic_present_simple_gerund
# Sample predictions: ['and', ',', ',', '##s', 'it']
# Sample expected: [' passing', ' living', ' growing', ' falling', ' picking']
# Sample predictions: [',', '.', ',', '!', 'to']
# Sample expected: [' rising', ' sparkling', ' wandering', ' staring', ' rushing']
# Baseline Accuracy: 0.00  (0.8s)
# ICL Accuracy: 0.00  (0.4s)
#
# ==================================================
# Running task 13/21: linguistic_present_simple_past_simple
# Sample predictions: ['.', 'on', '.', '##s', '##s']
# Sample expected: [' raced', ' noticed', ' headed', ' fell', ' read']
# Sample predictions: [',', '.', 'and', ',', '##s']
# Sample expected: [' put', ' failed', ' held', ' stepped', ' sensed']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.5s)
#
# ==================================================
# Running task 14/21: linguistic_present_simple_past_perfect
# WARNING: mapping present_simple_past_perfect has only 60 examples after filtering (110 before)
# Sample predictions: ['##s', '.', '##s', 'was', '##ed']
# Sample expected: [' heard', ' gone', ' fallen', ' cost', ' worn']
# Sample predictions: ['on', 'on', 'on', ',', 'with']
# Sample expected: [' found', ' known', ' sat', ' spun', ' worn']
# Baseline Accuracy: 0.00  (0.8s)
# ICL Accuracy: 0.00  (0.4s)
#
# ==================================================
# Running task 15/21: linguistic_singular_plural
# WARNING: mapping singular_plural has only 14 examples after filtering (173 before)
# Sample predictions: ['!', '.', '##s', ',', '!']
# Sample expected: [' heroes', ' feet', ' echoes', ' deer', ' heroes']
# Sample predictions: [',', '##s', ',', '.', '##s']
# Sample expected: [' feet', ' means', ' heroes', ' feet', ' châteaus']
# Baseline Accuracy: 0.00  (0.8s)
# ICL Accuracy: 0.00  (0.4s)
#
# ==================================================
# Running task 16/21: linguistic_plural_singular
# WARNING: mapping plural_singular has only 23 examples after filtering (172 before)
# Sample predictions: [',', '##s', ',', '!', ',']
# Sample expected: [' man', ' life', ' half', ' fish', ' man']
# Sample predictions: [',', ',', '##s', '.', ',']
# Sample expected: [' mouse', ' person', ' shelf', ' woman', ' deer']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.4s)
#
# ==================================================
# Running task 17/21: linguistic_antonyms
# Sample predictions: ['to', 'air', 'with', '.', '##s']
# Sample expected: [' follow', ' cold', ' sick', ' bright', ' right']
# Sample predictions: ['.', '.', '##s', '.', '.']
# Sample expected: [' warm', ' down', ' smooth', ' narrow', ' narrow']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.5s)
#
# ==================================================
# Running task 18/21: knowledge_country_capital
# Sample predictions: ['##ing', ',', '##s', '!', ',']
# Sample expected: ['Venice', 'Berlin', 'Paris', 'Berlin', 'Beijing']
# Sample predictions: [',', ',', '!', ',', ',']
# Sample expected: ['Athens', 'Mumbai', 'Dublin', 'Ankara', 'London']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.5s)
#
# ==================================================
# Running task 19/21: knowledge_person_language
# Sample predictions: [',', '!', ',', '?', '!']
# Sample expected: ['Ukrainian', 'English', 'Dutch', 'French', 'Italian']
# Sample predictions: [',', ',', '.', '!', ',']
# Sample expected: ['Russian', 'French', 'Dutch', 'Spanish', 'Spanish']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.5s)
#
# ==================================================
# Running task 20/21: knowledge_location_continent
# Sample predictions: ['##s', '!', ',', ',', '?']
# Sample expected: ['Asia', 'Antarctica', 'Antarctica', 'Africa', 'Antarctica']
# Sample predictions: [',', ',', ',', ',', '##ing']
# Sample expected: ['Asia', 'Africa', 'Antarctica', 'Antarctica', 'Antarctica']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.4s)
#
# ==================================================
# Running task 21/21: knowledge_location_religion
# Sample predictions: ['!', '.', ',', 'on', ',']
# Sample expected: ['Muslim', 'Jewish', 'Jewish', 'Christian', 'Jewish']
# Sample predictions: ['!', ',', '!', '!', ',']
# Sample expected: ['Muslim', 'Christian', 'Christian', 'Muslim', 'Muslim']
# Baseline Accuracy: 0.00  (0.9s)
# ICL Accuracy: 0.00  (0.5s)
#
# ============================================================
# Experiment: ~130M_pile
#
#   Loading ssm from HuggingFace: state-spaces/mamba-130m-hf
# config.json:   0%|          | 0.00/895 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/517M [00:00<?, ?B/s]
# The fast path is not available because one of `(selective_state_update, selective_scan_fn, causal_conv1d_fn, causal_conv1d_update, mamba_inner_fn)` is None. Falling back to the sequential implementation of Mamba, as use_mambapy is set to False. To install follow https://github.com/state-spaces/mamba/#installation for mamba-ssm and install the kernels library using `pip install kernels` or https://github.com/Dao-AILab/causal-conv1d for causal-conv1d. For the mamba.py backend, follow https://github.com/alxndrTL/mamba.py.
# Loading weights:   0%|          | 0/242 [00:00<?, ?it/s]
# MambaForCausalLM LOAD REPORT from: state-spaces/mamba-130m-hf
# Key            | Status  |
# ---------------+---------+-
# lm_head.weight | MISSING |
#
# Notes:
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]
# Evaluating ssm_~130M_pile on ICL...
#
# ==================================================
# Running task 1/21: algorithmic_next_letter
# Sample predictions: [' m', '', ' {', ' {', ' m']
# Sample expected: ['n', 'l', 'i', 'g', 'n']
# Sample predictions: [' z', ' v', ' q', ' y', ' y']
# Sample expected: ['z', 'v', 'o', 'y', 'w']
# Baseline Accuracy: 0.00  (3.1s)
# ICL Accuracy: 0.40  (3.7s)
#
# ==================================================
# Running task 2/21: algorithmic_prev_letter
# Sample predictions: [' {', ' {', '', ' g', ' {']
# Sample expected: ['m', 'k', 'h', 'f', 'm']
# Sample predictions: [' w', ' b', ' u', ' a', ' r']
# Sample expected: ['y', 'u', 'n', 'x', 'v']
# Baseline Accuracy: 0.00  (3.1s)
# ICL Accuracy: 0.06  (3.7s)
#
# ==================================================
# Running task 3/21: algorithmic_list_first
# Sample predictions: ['', ' {', ' {', ' {', ' {']
# Sample expected: ['i', 'p', 'w', 'r', 'y']
# Sample predictions: [' q', ' n', ' z', ' l', ' y']
# Sample expected: ['q', 'n', 'z', 'l', 'y']
# Baseline Accuracy: 0.15  (3.9s)
# ICL Accuracy: 1.00  (6.3s)
#
# ==================================================
# Running task 4/21: algorithmic_list_last
# Sample predictions: ['', ' {', ' {', ' {', ' {']
# Sample expected: ['x', 'o', 'a', 'v', 'z']
# Sample predictions: [' h', ' p', ' s', ' u', ' f']
# Sample expected: ['y', 'p', 's', 'u', 'f']
# Baseline Accuracy: 0.00  (3.9s)
# ICL Accuracy: 0.92  (6.2s)
#
# ==================================================
# Running task 5/21: algorithmic_list_min
# Sample predictions: ['', '', ' 0', '', ' 9']
# Sample expected: ['3', '5', '0', '6', '9']
# Sample predictions: [' 6', ' 5', ' 1', ' 4', ' 9']
# Sample expected: ['3', '5', '3', '4', '2']
# Baseline Accuracy: 0.26  (3.9s)
# ICL Accuracy: 0.54  (6.2s)
#
# ==================================================
# Running task 6/21: algorithmic_list_max
# Sample predictions: ['', '', ' 0', '', ' 9']
# Sample expected: ['9', '6', '8', '8', '9']
# Sample predictions: [' 6', ' 5', ' 9', ' 4', ' 9']
# Sample expected: ['9', '7', '9', '7', '9']
# Baseline Accuracy: 0.03  (3.9s)
# ICL Accuracy: 0.48  (6.3s)
#
# ==================================================
# Running task 7/21: algorithmic_list_length
# Sample predictions: ['', ' {', '', '', '']
# Sample expected: ['2', '2', '3', '1', '3']
# Sample predictions: [' 3', ' 1', ' 1', ' 1', ' 2']
# Sample expected: ['1', '3', '1', '1', '2']
# Baseline Accuracy: 0.00  (3.5s)
# ICL Accuracy: 0.56  (5.0s)
#
# ==================================================
# Running task 8/21: algorithmic_to_upper
# Sample predictions: [' m', '', ' {', ' {', ' m']
# Sample expected: ['M', 'K', 'H', 'F', 'M']
# Sample predictions: [' B', ' E', ' T', ' H', ' X']
# Sample expected: ['B', 'E', 'T', 'H', 'X']
# Baseline Accuracy: 0.00  (3.0s)
# ICL Accuracy: 1.00  (3.7s)
#
# ==================================================
# Running task 9/21: algorithmic_to_lower
# Sample predictions: [' M', '', ' {', ' {', ' M']
# Sample expected: ['m', 'k', 'h', 'f', 'm']
# Sample predictions: [' b', ' e', ' t', ' h', ' x']
# Sample expected: ['b', 'e', 't', 'h', 'x']
# Baseline Accuracy: 0.00  (3.1s)
# ICL Accuracy: 1.00  (3.7s)
#
# ==================================================
# Running task 10/21: algorithmic_char_to_int
# Sample predictions: [' g', ' {', '', '', ' g']
# Sample expected: ['7', '6', '4', '3', '7']
# Sample predictions: [' 1', ' 3', ' 10', ' 4', ' 9']
# Sample expected: ['1', '4', '7', '9', '1']
# Baseline Accuracy: 0.00  (3.0s)
# ICL Accuracy: 0.08  (3.7s)
#
# ==================================================
# Running task 11/21: algorithmic_int_to_char
# Sample predictions: ['', '', '', '', '']
# Sample expected: ['g', 'f', 'd', 'c', 'g']
# Sample predictions: [' a', ' c', ' f', ' a', ' i']
# Sample expected: ['a', 'd', 'g', 'i', 'a']
# Baseline Accuracy: 0.00  (3.1s)
# ICL Accuracy: 0.22  (3.7s)
#
# ==================================================
# Running task 12/21: linguistic_present_simple_gerund
# Sample predictions: ['', '', '', '', '']
# Sample expected: [' quoting', ' offering', ' handing', ' eating', ' reaching']
# Sample predictions: ['  ', '  ', '  ', '  ', '  ']
# Sample expected: [' backing', ' healing', ' growing', ' switching', ' examining']
# Baseline Accuracy: 0.00  (3.0s)
# ICL Accuracy: 0.00  (4.8s)
#
# ==================================================
# Running task 13/21: linguistic_present_simple_past_simple
# Sample predictions: ['', '', '', ' draw', ' pick']
# Sample expected: [' peeled', ' locked', ' forgot', ' drew', ' picked']
# Sample predictions: ['  ', '  ', '  ', '  ', '  ']
# Sample expected: [' parted', ' caught', ' flooded', ' stretched', ' cost']
# Baseline Accuracy: 0.00  (3.0s)
# ICL Accuracy: 0.00  (4.7s)
#
# ==================================================
# Running task 14/21: linguistic_present_simple_past_perfect
# Sample predictions: ['', '', '', ' draw', '']
# Sample expected: [' made', ' known', ' flown', ' drawn', ' meant']
# Sample predictions: ['  ', '  ', '  ', '  ', '  ']
# Sample expected: [' let', ' grown', ' kept', ' fought', ' driven']
# Baseline Accuracy: 0.00  (3.1s)
# ICL Accuracy: 0.00  (4.5s)
#
# ==================================================
# Running task 15/21: linguistic_singular_plural
# Sample predictions: ['', ' mouse', '', ' fish', '']
# Sample expected: [' people', ' mice', ' hypotheses', ' fish', ' phenomena']
# Sample predictions: ['  ', '  ', '  ', '  ', '  ']
# Sample expected: [' analyses', ' indices', ' hypotheses', ' those', ' echoes']
# Baseline Accuracy: 0.12  (3.0s)
# ICL Accuracy: 0.00  (4.8s)
#
# ==================================================
# Running task 16/21: linguistic_plural_singular
# Sample predictions: [' measles', '', '', ' deer', '']
# Sample expected: [' measles', ' leaf', ' foot', ' deer', ' medium']
# Sample predictions: ['  ', '  ', '  ', '  ', '  ']
# Sample expected: [' vertex', ' swine', ' emphasis', ' vortex', ' series']
# Baseline Accuracy: 0.10  (3.2s)
# ICL Accuracy: 0.00  (4.9s)
#
# ==================================================
# Running task 17/21: linguistic_antonyms
# Sample predictions: ['', '', '', '', '']
# Sample expected: [' even', ' quiet', ' stop', ' succeed', ' refuse']
# Sample predictions: ['  ', '  ', '  ', '  ', '  ']
# Sample expected: [' even', ' succeed', ' innocent', ' dangerous', ' loud']
# Baseline Accuracy: 0.06  (3.1s)
# ICL Accuracy: 0.00  (4.4s)
#
# ==================================================
# Running task 18/21: knowledge_country_capital
# Sample predictions: [' Italy', ' Germany', ' France', ' Germany', ' Q']
# Sample expected: ['Venice', 'Berlin', 'Paris', 'Berlin', 'Beijing']
# Sample predictions: [' Athens', ' Mumbai', ' Dublin', ' An', ' New']
# Sample expected: ['Athens', 'Mumbai', 'Dublin', 'Ankara', 'London']
# Baseline Accuracy: 0.15  (3.6s)
# ICL Accuracy: 0.48  (5.6s)
#
# ==================================================
# Running task 19/21: knowledge_person_language
# Sample predictions: ['', ' G', ' @', '', ' I']
# Sample expected: ['Ukrainian', 'English', 'Dutch', 'French', 'Italian']
# Sample predictions: [' Russian', ' French', ' Dutch', ' Spanish', ' Spanish']
# Sample expected: ['Russian', 'French', 'Dutch', 'Spanish', 'Spanish']
# Baseline Accuracy: 0.04  (4.0s)
# ICL Accuracy: 0.72  (6.3s)
#
# ==================================================
# Running task 20/21: knowledge_location_continent
# Sample predictions: ['', ' Gl', ' D', ' Chad', ' West']
# Sample expected: ['Asia', 'Antarctica', 'Antarctica', 'Africa', 'Antarctica']
# Sample predictions: [' Asia', ' Antar', ' Antar', ' Antar', ' Antar']
# Sample expected: ['Asia', 'Africa', 'Antarctica', 'Antarctica', 'Antarctica']
# Baseline Accuracy: 0.00  (3.7s)
# ICL Accuracy: 0.74  (5.9s)
#
# ==================================================
# Running task 21/21: knowledge_location_religion
# Sample predictions: [' K', '', ' K', '', '']
# Sample expected: ['Muslim', 'Jewish', 'Jewish', 'Christian', 'Jewish']
# Sample predictions: [' Muslim', ' Muslim', ' Muslim', ' Muslim', ' Muslim']
# Sample expected: ['Muslim', 'Christian', 'Christian', 'Muslim', 'Muslim']
# Baseline Accuracy: 0.04  (4.0s)
# ICL Accuracy: 0.72  (6.5s)
#
#   Loading transformer from HuggingFace: EleutherAI/pythia-160m
# config.json:   0%|          | 0.00/569 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/396 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/375M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Evaluating transformer_~130M_pile on ICL...
#
# ==================================================
# Running task 1/21: algorithmic_next_letter
# Sample predictions: ['', ' {', '', ' "', '']
# Sample expected: ['n', 'l', 'i', 'g', 'n']
# Sample predictions: [' z', ' s', ' p', ' e', ' j']
# Sample expected: ['z', 'v', 'o', 'y', 'w']
# Baseline Accuracy: 0.00  (1.2s)
# ICL Accuracy: 0.38  (0.5s)
#
# ==================================================
# Running task 2/21: algorithmic_prev_letter
# Sample predictions: [' "', '', '', '', ' "']
# Sample expected: ['m', 'k', 'h', 'f', 'm']
# Sample predictions: [' z', ' w', ' l', ' d', ' h']
# Sample expected: ['y', 'u', 'n', 'x', 'v']
# Baseline Accuracy: 0.00  (1.1s)
# ICL Accuracy: 0.02  (0.6s)
#
# ==================================================
# Running task 3/21: algorithmic_list_first
# Sample predictions: [' 0', ' 0', ' a', ' v', ' z']
# Sample expected: ['i', 'p', 'w', 'r', 'y']
# Sample predictions: [' q', ' t', ' h', ' l', ' f']
# Sample expected: ['q', 'n', 'z', 'l', 'y']
# Baseline Accuracy: 0.02  (1.1s)
# ICL Accuracy: 0.66  (0.6s)
#
# ==================================================
# Running task 4/21: algorithmic_list_last
# Sample predictions: [' 0', ' 0', ' a', ' v', ' z']
# Sample expected: ['x', 'o', 'a', 'v', 'z']
# Sample predictions: [' y', ' r', ' s', ' l', ' f']
# Sample expected: ['y', 'p', 's', 'u', 'f']
# Baseline Accuracy: 0.53  (1.1s)
# ICL Accuracy: 0.64  (0.6s)
#
# ==================================================
# Running task 5/21: algorithmic_list_min
# Sample predictions: [' 1', ' 5', ' 0', ' 8', ' 9']
# Sample expected: ['3', '5', '0', '6', '9']
# Sample predictions: [' 3', ' 5', ' 1', ' 5', ' 2']
# Sample expected: ['3', '5', '3', '4', '2']
# Baseline Accuracy: 0.67  (1.1s)
# ICL Accuracy: 0.44  (0.6s)
#
# ==================================================
# Running task 6/21: algorithmic_list_max
# Sample predictions: [' 1', ' 5', ' 0', ' 8', ' 9']
# Sample expected: ['9', '6', '8', '8', '9']
# Sample predictions: [' 6', ' 5', ' 9', ' 4', ' 6']
# Sample expected: ['9', '7', '9', '7', '9']
# Baseline Accuracy: 0.14  (1.1s)
# ICL Accuracy: 0.36  (0.6s)
#
# ==================================================
# Running task 7/21: algorithmic_list_length
# Sample predictions: [' z', ' r', ' 0', '', ' a']
# Sample expected: ['2', '2', '3', '1', '3']
# Sample predictions: [' 3', ' 3', ' 2', ' 1', ' 2']
# Sample expected: ['1', '3', '1', '1', '2']
# Baseline Accuracy: 0.00  (1.1s)
# ICL Accuracy: 0.46  (0.6s)
#
# ==================================================
# Running task 8/21: algorithmic_to_upper
# Sample predictions: ['', ' {', '', ' "', '']
# Sample expected: ['M', 'K', 'H', 'F', 'M']
# Sample predictions: [' Y', ' E', ' H', ' W', ' X']
# Sample expected: ['B', 'E', 'T', 'H', 'X']
# Baseline Accuracy: 0.00  (1.1s)
# ICL Accuracy: 0.70  (0.6s)
#
# ==================================================
# Running task 9/21: algorithmic_to_lower
# Sample predictions: ['', '', '', '', '']
# Sample expected: ['m', 'k', 'h', 'f', 'm']
# Sample predictions: [' b', ' e', ' t', ' h', ' y']
# Sample expected: ['b', 'e', 't', 'h', 'x']
# Baseline Accuracy: 0.00  (1.1s)
# ICL Accuracy: 0.94  (0.6s)
#
# ==================================================
# Running task 10/21: algorithmic_char_to_int
# Sample predictions: ['', ' "', '', ' "', '']
# Sample expected: ['7', '6', '4', '3', '7']
# Sample predictions: [' 3', ' 3', ' 10', ' 6', ' 3']
# Sample expected: ['1', '4', '7', '9', '1']
# Baseline Accuracy: 0.00  (1.0s)
# ICL Accuracy: 0.06  (0.6s)
#
# ==================================================
# Running task 11/21: algorithmic_int_to_char
# Sample predictions: ['', '', '', '', '']
# Sample expected: ['g', 'f', 'd', 'c', 'g']
# Sample predictions: [' c', ' c', ' j', ' f', ' i']
# Sample expected: ['a', 'd', 'g', 'i', 'a']
# Baseline Accuracy: 0.00  (1.1s)
# ICL Accuracy: 0.08  (0.6s)
#
# ==================================================
# Running task 12/21: linguistic_present_simple_gerund
# Sample predictions: [' "', '', ' "', '', '']
# Sample expected: [' quoting', ' offering', ' handing', ' eating', ' reaching']
# Sample predictions: ['  ', '  ', '  ', '  ', '  ']
# Sample expected: [' backing', ' healing', ' growing', ' switching', ' examining']
# Baseline Accuracy: 0.00  (1.1s)
# ICL Accuracy: 0.00  (0.6s)
#
# ==================================================
# Running task 13/21: linguistic_present_simple_past_simple
# Sample predictions: [' "', '', '', '', '']
# Sample expected: [' peeled', ' locked', ' forgot', ' drew', ' picked']
# Sample predictions: ['  ', '  ', '  ', '  ', '  ']
# Sample expected: [' parted', ' caught', ' flooded', ' stretched', ' cost']
# Baseline Accuracy: 0.00  (1.1s)
# ICL Accuracy: 0.00  (0.5s)
#
# ==================================================
# Running task 14/21: linguistic_present_simple_past_perfect
# Sample predictions: ['', '', '', '', ' "']
# Sample expected: [' made', ' known', ' flown', ' drawn', ' meant']
# Sample predictions: ['  ', '  ', '  ', '  ', '  ']
# Sample expected: [' let', ' grown', ' kept', ' fought', ' driven']
# Baseline Accuracy: 0.00  (1.1s)
# ICL Accuracy: 0.00  (0.6s)
#
# ==================================================
# Running task 15/21: linguistic_singular_plural
# Sample predictions: ['', ' mouse', '', '', '']
# Sample expected: [' people', ' mice', ' hypotheses', ' fish', ' phenomena']
# Sample predictions: ['  ', '  ', '  ', '  ', '  ']
# Sample expected: [' analyses', ' indices', ' hypotheses', ' those', ' echoes']
# Baseline Accuracy: 0.00  (1.1s)
# ICL Accuracy: 0.00  (0.6s)
#
# ==================================================
# Running task 16/21: linguistic_plural_singular
# Sample predictions: ['', '', '', '', '']
# Sample expected: [' measles', ' leaf', ' foot', ' deer', ' medium']
# Sample predictions: ['  ', '  ', '  ', '  ', '  ']
# Sample expected: [' vertex', ' swine', ' emphasis', ' vortex', ' series']
# Baseline Accuracy: 0.00  (1.1s)
# ICL Accuracy: 0.00  (0.6s)
#
# ==================================================
# Running task 17/21: linguistic_antonyms
# Sample predictions: ['', '', '', '', '']
# Sample expected: [' even', ' quiet', ' stop', ' succeed', ' refuse']
# Sample predictions: ['  ', '  ', '  ', '  ', '  ']
# Sample expected: [' even', ' succeed', ' innocent', ' dangerous', ' loud']
# Baseline Accuracy: 0.00  (1.1s)
# ICL Accuracy: 0.00  (0.6s)
#
# ==================================================
# Running task 18/21: knowledge_country_capital
# Sample predictions: ['', ' Germany', ' France', ' Pruss', ' the']
# Sample expected: ['Venice', 'Berlin', 'Paris', 'Berlin', 'Beijing']
# Sample predictions: [' Budapest', ' Mumbai', ' Dublin', ' D', ' London']
# Sample expected: ['Athens', 'Mumbai', 'Dublin', 'Ankara', 'London']
# Baseline Accuracy: 0.11  (1.1s)
# ICL Accuracy: 0.46  (0.6s)
#
# ==================================================
# Running task 19/21: knowledge_person_language
# Sample predictions: ['', ' "', '', '', '']
# Sample expected: ['Ukrainian', 'English', 'Dutch', 'French', 'Italian']
# Sample predictions: [' Russian', ' French', ' Dutch', ' Spanish', ' French']
# Sample expected: ['Russian', 'French', 'Dutch', 'Spanish', 'Spanish']
# Baseline Accuracy: 0.00  (1.1s)
# ICL Accuracy: 0.40  (0.6s)
#
# ==================================================
# Running task 20/21: knowledge_location_continent
# Sample predictions: [' University', '', '', '', ' Antar']
# Sample expected: ['Asia', 'Antarctica', 'Antarctica', 'Africa', 'Antarctica']
# Sample predictions: [' Turkey', ' Antar', ' Antar', ' Antar', ' Antar']
# Sample expected: ['Asia', 'Africa', 'Antarctica', 'Antarctica', 'Antarctica']
# Baseline Accuracy: 0.01  (1.1s)
# ICL Accuracy: 0.70  (0.6s)
#
# ==================================================
# Running task 21/21: knowledge_location_religion
# Sample predictions: [' K', '', '', ' "', ' Cl']
# Sample expected: ['Muslim', 'Jewish', 'Jewish', 'Christian', 'Jewish']
# Sample predictions: [' Muslim', ' Muslim', ' Muslim', ' Muslim', ' Muslim']
# Sample expected: ['Muslim', 'Christian', 'Christian', 'Muslim', 'Muslim']
# Baseline Accuracy: 0.00  (1.1s)
# ICL Accuracy: 0.66  (0.6s)
#
# ============================================================
# Experiment: ~370M_pile
#
#   Loading ssm from HuggingFace: state-spaces/mamba-370m-hf
# config.json:   0%|          | 0.00/917 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.49G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/482 [00:00<?, ?it/s]
# MambaForCausalLM LOAD REPORT from: state-spaces/mamba-370m-hf
# Key            | Status  |
# ---------------+---------+-
# lm_head.weight | MISSING |
#
# Notes:
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]
# Evaluating ssm_~370M_pile on ICL...
#
# ==================================================
# Running task 1/21: algorithmic_next_letter
# Sample predictions: [' m', ' k', ' h', '', ' m']
# Sample expected: ['n', 'l', 'i', 'g', 'n']
# Sample predictions: [' z', ' v', ' q', ' e', ' y']
# Sample expected: ['z', 'v', 'o', 'y', 'w']
# Baseline Accuracy: 0.00  (6.1s)
# ICL Accuracy: 0.44  (7.5s)
#
# ==================================================
# Running task 2/21: algorithmic_prev_letter
# Sample predictions: [' (', '', '', '', ' (']
# Sample expected: ['m', 'k', 'h', 'f', 'm']
# Sample predictions: [' w', ' p', ' r', ' a', ' h']
# Sample expected: ['y', 'u', 'n', 'x', 'v']
# Baseline Accuracy: 0.00  (6.1s)
# ICL Accuracy: 0.06  (7.4s)
#
# ==================================================
# Running task 3/21: algorithmic_list_first
# Sample predictions: ['', '', '', '', ' y']
# Sample expected: ['i', 'p', 'w', 'r', 'y']
# Sample predictions: [' q', ' n', ' z', ' l', ' y']
# Sample expected: ['q', 'n', 'z', 'l', 'y']
# Baseline Accuracy: 0.10  (7.7s)
# ICL Accuracy: 1.00  (12.4s)
#
# ==================================================
# Running task 4/21: algorithmic_list_last
# Sample predictions: ['', '', '', '', ' y']
# Sample expected: ['x', 'o', 'a', 'v', 'z']
# Sample predictions: [' y', ' r', ' s', ' u', ' f']
# Sample expected: ['y', 'p', 's', 'u', 'f']
# Baseline Accuracy: 0.02  (7.7s)
# ICL Accuracy: 0.86  (12.5s)
#
# ==================================================
# Running task 5/21: algorithmic_list_min
# Sample predictions: [' 9', ' 5', ' 0', ' (', ' 9']
# Sample expected: ['3', '5', '0', '6', '9']
# Sample predictions: [' 3', ' 5', ' 3', ' 4', ' 9']
# Sample expected: ['3', '5', '3', '4', '2']
# Baseline Accuracy: 0.44  (7.7s)
# ICL Accuracy: 0.68  (12.4s)
#
# ==================================================
# Running task 6/21: algorithmic_list_max
# Sample predictions: [' 9', ' 5', ' 0', ' (', ' 9']
# Sample expected: ['9', '6', '8', '8', '9']
# Sample predictions: [' 9', ' 5', ' 7', ' 7', ' 9']
# Sample expected: ['9', '7', '9', '7', '9']
# Baseline Accuracy: 0.19  (7.7s)
# ICL Accuracy: 0.64  (12.3s)
#
# ==================================================
# Running task 7/21: algorithmic_list_length
# Sample predictions: ['', '', '', ' u', '']
# Sample expected: ['2', '2', '3', '1', '3']
# Sample predictions: [' 3', ' 1', ' 1', ' 1', ' 2']
# Sample expected: ['1', '3', '1', '1', '2']
# Baseline Accuracy: 0.00  (7.0s)
# ICL Accuracy: 0.54  (10.0s)
#
# ==================================================
# Running task 8/21: algorithmic_to_upper
# Sample predictions: [' m', ' k', ' h', '', ' m']
# Sample expected: ['M', 'K', 'H', 'F', 'M']
# Sample predictions: [' B', ' E', ' T', ' H', ' X']
# Sample expected: ['B', 'E', 'T', 'H', 'X']
# Baseline Accuracy: 0.00  (6.0s)
# ICL Accuracy: 1.00  (7.4s)
#
# ==================================================
# Running task 9/21: algorithmic_to_lower
# Sample predictions: [' M', ' K', ' H', '', ' M']
# Sample expected: ['m', 'k', 'h', 'f', 'm']
# Sample predictions: [' b', ' e', ' t', ' h', ' x']
# Sample expected: ['b', 'e', 't', 'h', 'x']
# Baseline Accuracy: 0.00  (5.9s)
# ICL Accuracy: 1.00  (7.4s)
#
# ==================================================
# Running task 10/21: algorithmic_char_to_int
# Sample predictions: ['', '', ' d', '', '']
# Sample expected: ['7', '6', '4', '3', '7']
# Sample predictions: [' 1', ' 3', ' 6', ' 7', ' 9']
# Sample expected: ['1', '4', '7', '9', '1']
# Baseline Accuracy: 0.00  (6.0s)
# ICL Accuracy: 0.16  (7.3s)
#
# ==================================================
# Running task 11/21: algorithmic_int_to_char
# Sample predictions: [' (', '', '', ' 2', ' (']
# Sample expected: ['g', 'f', 'd', 'c', 'g']
# Sample predictions: [' a', ' c', ' f', ' g', ' b']
# Sample expected: ['a', 'd', 'g', 'i', 'a']
# Baseline Accuracy: 0.00  (6.0s)
# ICL Accuracy: 0.24  (7.4s)
#
# ==================================================
# Running task 12/21: linguistic_present_simple_gerund
# Sample predictions: ['', '', '', '', '']
# Sample expected: [' quoting', ' offering', ' handing', ' eating', ' reaching']
# Sample predictions: ['  ', '  ', '  ', '  ', '  ']
# Sample expected: [' backing', ' healing', ' growing', ' switching', ' examining']
# Baseline Accuracy: 0.00  (6.0s)
# ICL Accuracy: 0.00  (9.5s)
#
# ==================================================
# Running task 13/21: linguistic_present_simple_past_simple
# Sample predictions: ['', ' lock', '', ' draw', ' pick']
# Sample expected: [' peeled', ' locked', ' forgot', ' drew', ' picked']
# Sample predictions: ['  ', '  ', '  ', '  ', '  ']
# Sample expected: [' parted', ' caught', ' flooded', ' stretched', ' cost']
# Baseline Accuracy: 0.00  (6.1s)
# ICL Accuracy: 0.00  (9.4s)
#
# ==================================================
# Running task 14/21: linguistic_present_simple_past_perfect
# Sample predictions: ['', '', ' fly', ' draw', ' mean']
# Sample expected: [' made', ' known', ' flown', ' drawn', ' meant']
# Sample predictions: ['  ', '  ', '  ', '  ', '  ']
# Sample expected: [' let', ' grown', ' kept', ' fought', ' driven']
# Baseline Accuracy: 0.00  (6.0s)
# ICL Accuracy: 0.00  (9.0s)
#
# ==================================================
# Running task 15/21: linguistic_singular_plural
# Sample predictions: [' person', ' mouse', '', ' fish', '']
# Sample expected: [' people', ' mice', ' hypotheses', ' fish', ' phenomena']
# Sample predictions: ['  ', '  ', '  ', '  ', '  ']
# Sample expected: [' analyses', ' indices', ' hypotheses', ' those', ' echoes']
# Baseline Accuracy: 0.10  (6.1s)
# ICL Accuracy: 0.00  (9.6s)
#
# ==================================================
# Running task 16/21: linguistic_plural_singular
# Sample predictions: [' measles', '', '', ' deer', ' media']
# Sample expected: [' measles', ' leaf', ' foot', ' deer', ' medium']
# Sample predictions: ['  ', '  ', '  ', '  ', '  ']
# Sample expected: [' vertex', ' swine', ' emphasis', ' vortex', ' series']
# Baseline Accuracy: 0.06  (6.2s)
# ICL Accuracy: 0.00  (9.8s)
#
# ==================================================
# Running task 17/21: linguistic_antonyms
# Sample predictions: [' odd', ' loud', '', '', '']
# Sample expected: [' even', ' quiet', ' stop', ' succeed', ' refuse']
# Sample predictions: ['  ', '  ', '  ', '  ', '  ']
# Sample expected: [' even', ' succeed', ' innocent', ' dangerous', ' loud']
# Baseline Accuracy: 0.20  (6.0s)
# ICL Accuracy: 0.00  (8.6s)
#
# ==================================================
# Running task 18/21: knowledge_country_capital
# Sample predictions: [' Venice', ' Nazi', ' France', ' Pruss', ' Ming']
# Sample expected: ['Venice', 'Berlin', 'Paris', 'Berlin', 'Beijing']
# Sample predictions: [' Athens', ' Mumbai', ' Dublin', ' Ank', ' London']
# Sample expected: ['Athens', 'Mumbai', 'Dublin', 'Ankara', 'London']
# Baseline Accuracy: 0.15  (7.1s)
# ICL Accuracy: 0.78  (11.0s)
#
# ==================================================
# Running task 19/21: knowledge_person_language
# Sample predictions: [' Ivan', ' "', ' Eric', '', ' I']
# Sample expected: ['Ukrainian', 'English', 'Dutch', 'French', 'Italian']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3832/4033333609.py in <cell line: 0>()
#       3
#       4 from experiment_pretrained_icl import run_experiments
# ----> 5 run_experiments()
#
# /content/csci739-project-mamba/experiments/experiment_pretrained_icl.py in run_experiments(device)
#      94
#      95
# ---> 96             run_main_experiment(
#      97                 model,
#      98                 tokenizer,
#
# /content/csci739-project-mamba/experiments/icl_tasks.py in run_main_experiment(model, tokenizer, model_type, model_variant)
#     164
#     165
# --> 166         accuracies, confusion_matrices, timings = evaluate_task(model, tokenizer, task_name, num_examples)
#     167
#     168         if torch.cuda.is_available():
#
# /content/csci739-project-mamba/experiments/icl_tasks.py in evaluate_task(model, tokenizer, task_name, num_examples)
#     119     test_datasets = task.create_datasets(num_datasets=num_test_datasets, num_examples=num_examples)
#     120     tic = time.time()
# --> 121     icl_predictions = run_icl(model, tokenizer, test_datasets)
#     122     timings["icl"] = time.time() - tic
#     123
#
# /content/csci739-project-mamba/experiments/icl_tasks.py in run_icl(model, tokenizer, test_datasets, include_train)
#      92     format_dataset_kwargs = {"include_train": include_train}
#      93     inputs = tokenize_datasets(tokenizer, test_datasets, format_dataset_kwargs=format_dataset_kwargs)
# ---> 94     new_ids = batch_generate(model, tokenizer, inputs=inputs, generate_kwargs={"max_new_tokens": 1})
#      95     predictions = decode_predictions(new_ids, tokenizer)
#      96     print("Sample predictions:", predictions[:5])
#
# /content/csci739-project-mamba/experiments/mamba_inference.py in batch_generate(model, tokenizer, inputs, generate_kwargs, batch_size)
#      63                 for j in range(batch_ids.shape[0]):
#      64                     real_ids = batch_ids[j][batch_mask[j].bool()].unsqueeze(0)
# ---> 65                     raw_output = model(real_ids)
#      66                     logits = _extract_logits(raw_output)
#      67                     next_token = logits[0, -1, :].argmax()
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/mamba/modeling_mamba.py in forward(self, input_ids, attention_mask, inputs_embeds, cache_params, labels, output_hidden_states, return_dict, use_cache, cache_position, logits_to_keep, **kwargs)
#     819         return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#     820
# --> 821         mamba_outputs = self.backbone(
#     822             input_ids,
#     823             cache_params=cache_params,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/mamba/modeling_mamba.py in forward(self, input_ids, inputs_embeds, cache_params, use_cache, output_hidden_states, return_dict, cache_position, attention_mask, **kwargs)
#     676         all_hidden_states = () if output_hidden_states else None
#     677         for mixer_block in self.layers:
# --> 678             hidden_states = mixer_block(
#     679                 hidden_states,
#     680                 cache_params=cache_params,
#
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_layers.py in __call__(self, *args, **kwargs)
#      91
#      92             return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 93         return super().__call__(*args, **kwargs)
#      94
#      95
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1774             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775         else:
# -> 1776             return self._call_impl(*args, **kwargs)
#    1777
#    1778     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1785                 or _global_backward_pre_hooks or _global_backward_hooks
#    1786                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787             return forward_call(*args, **kwargs)
#    1788
#    1789         result = None
#
# KeyboardInterrupt:
